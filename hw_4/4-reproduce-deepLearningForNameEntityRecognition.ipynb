# %% [markdown]
# # HW4-DL for Name Entity Recognition (NER)
#
# - Detravious Jamari Brinkley
# - CSCI-544: Applied Natural Language Processing
# - python version: 3
#
# ---
#
# - Name Entity Recognition []

# %%
# imports
import torch

import numpy as np
import pandas as pd


import torch.nn as nn
import torch.optim as optim

from tqdm import tqdm

from torch.nn.utils.rnn import pad_sequence
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
# Out:
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_80077/2159215202.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv("../datasets/ner_practice/ner_dataset.csv", encoding="latin1")
data = data.fillna(method="ffill")
data
# Out:
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_80077/2743975830.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method="ffill")
#               Sentence #           Word  POS Tag
# 0            Sentence: 1      Thousands  NNS   O
# 1            Sentence: 1             of   IN   O
# 2            Sentence: 1  demonstrators  NNS   O
# 3            Sentence: 1           have  VBP   O
# 4            Sentence: 1        marched  VBN   O
# ...                  ...            ...  ...  ..
# 1048570  Sentence: 47959           they  PRP   O
# 1048571  Sentence: 47959      responded  VBD   O
# 1048572  Sentence: 47959             to   TO   O
# 1048573  Sentence: 47959            the   DT   O
# 1048574  Sentence: 47959         attack   NN   O
#
# [1048575 rows x 4 columns]

# %%
def update_index(df):
    current_col = None
    new_index = 0  # Initial new index
    # empty_row = pd.DataFrame(columns=df.columns)

    for i, row in df.iterrows():
        # Check if column name changes
        if current_col != row['Sentence #']:
            current_col = row['Sentence #']
            new_index = 1  # Reset new index to 1
            
            empty_row = pd.Series([None] * len(df.columns), index=df.columns)
            
        df.at[i, 'New Sentence Index'] = new_index
        new_index += 1  # Increment new index
        
    return df

# %%
# Add a new column 'Index' and update it
data['New Sentence Index'] = None
data = update_index(data)
data.drop(columns=["Sentence #", "POS"], inplace=True)
data.rename(columns={'Tag': 'NER Tag'}, inplace=True)

# %%
def add_empty_row(df):
    new_rows = []
    for index, row in df.iterrows():
        if row['New Sentence Index'] == 1:
            empty_row = pd.Series([''] * len(row), index=row.index)
            new_rows.append(empty_row)
        new_rows.append(row)
    return pd.DataFrame(new_rows)

# %%
data = add_empty_row(data)
data.reset_index(inplace=True)
data.drop(columns=["index"], inplace=True)
data = data.iloc[1:]

# %%
data
# Out:
#                   Word NER Tag New Sentence Index
# 1            Thousands       O                  1
# 2                   of       O                  2
# 3        demonstrators       O                  3
# 4                 have       O                  4
# 5              marched       O                  5
# ...                ...     ...                ...
# 1096529           they       O                  4
# 1096530      responded       O                  5
# 1096531             to       O                  6
# 1096532            the       O                  7
# 1096533         attack       O                  8
#
# [1096533 rows x 3 columns]

# %%
def get_stats(df, col_name):
    print(f"Unique {col_name} in corpus:", df[col_name].nunique())

    values_in_col_name = list(set(data[col_name].values))[1:]
    len_of_col_name = len(values_in_col_name)

    return len_of_col_name, values_in_col_name

# %%
def create_mappings(input_to_map):
    """Pair word with corresponding index"""

    word_to_index = {}

    for idx, word in tqdm(enumerate(input_to_map)):
        # If the word is not already in the dictionary, add it with its index
        # if word not in word_to_index:
        # word_to_index[word] = input_to_map.index(word)
        word_to_index[word] = idx + 1
    return word_to_index

# %%
num_words, words = get_stats(data, "Word")
num_words, words
# Out:
# Unique Word in corpus: 35178
# (35177,
#  ['rampage',
#   '405',
#   'pouring',
#   'appear',
#   'Casamance',
#   'incensed',
#   'Alzouma',
#   'Dayton',
#   'snag',
#   'Bernanke',
#   'grounds',
#   'allot',
#   'outperformed',
#   'Xinhua',
#   'boastful',
#   'Sarawak',
#   'estimated',
#   'apprehended',
#   'Pondicherry',
#   'Carreno',
#   'assassins',
#   'exemption',
#   'realizes',
#   'Teir',
#   'Kirkuk',
#   'sketch',
#   'caverns',
#   'Scilingo',
#   'grip',
#   'gridlock',
#   'fatigues',
#   'Salafist',
#   'good-bye',
#   'Sadat',
#   'war-damaged',
#   'involving',
#   'Congressman',
#   'Cleric',
#   'Dalian',
#   'notional',
#   'Anabel',
#   'relied',
#   'tamed',
#   'Dobrynska',
#   'Payne',
#   'behaviour',
#   'go-betweens',
#   'sleeve',
#   'arthritis',
#   'westward',
#   'Blanco',
#   'Saparmurat',
#   'overburdened',
#   'pontificate',
#   'Caspian',
#   'constraints',
#   '170-meter',
#   'Fadilah',
#   'supervising',
#   'Si',
#   'uncontrolled',
#   'wall',
#   'hospitalized',
#   'hotel',
#   'shafts',
#   'Zabul',
#   'deteriorates',
#   'cancers',
#   'Tito',
#   'al-Maliky',
#   'ringleader',
#   'N.J.',
#   'Arabiya',
#   'acceptable',
#   'Scientists',
#   '1648',
#   'darkness',
#   'Tidal',
#   'SAAKASHVILI',
#   'Managing',
#   'Endowment',
#   'al-Watan',
#   'Seibu',
#   'Marghzar',
#   'hyperinflation',
#   'sophisticated',
#   'format',
#   'tall',
#   'Ted',
#   'humiliation',
#   'complicated',
#   'Doetinchem',
#   'Gasquet',
#   'pressures',
#   'Belet',
#   'introduces',
#   'Eduard',
#   'J.P.',
#   'downstream',
#   'Enterprise',
#   'balances',
#   'Préval',
#   'defused',
#   'vocation',
#   'Surkhanpha',
#   'contrasts',
#   'unmanned',
#   'Machinists',
#   'Confessed',
#   'July-August',
#   'hijacking',
#   'reshuffling',
#   'Simone',
#   'materialized',
#   'enemies',
#   'estates',
#   'Christofias',
#   'anti-violence',
#   'leveling',
#   'Danielle',
#   'Goats',
#   'Substantial',
#   'urban',
#   'Alcantara',
#   'Novosti',
#   'Nimroz',
#   'tables',
#   'malnourished',
#   'important',
#   'quarantine',
#   'JVP',
#   'Bears',
#   're-invest',
#   'Rica',
#   'instigating',
#   'Pinas',
#   'occupying',
#   'aragonite',
#   '50th',
#   'military-owned',
#   'Completing',
#   '500-meter',
#   'Bralo',
#   'CPJ',
#   'stemming',
#   'Krasniqi',
#   'strenuously',
#   '300-member',
#   'Yuri',
#   'Novak',
#   'expenditures',
#   'Agim',
#   'Dissostichus',
#   'flames',
#   'Lindsey',
#   'counsel-general',
#   'Maazou',
#   'build-up',
#   'contradicted',
#   'spiral',
#   'domain',
#   'THIEF',
#   'Al-Shihri',
#   '17-month',
#   'Chigwedere',
#   '452',
#   'watchful',
#   '7.30',
#   'jockeys',
#   'labors',
#   'Keraterm',
#   'dioxin',
#   'Seeing',
#   'scholars',
#   'debating',
#   'Golding',
#   'beginning',
#   'asserting',
#   'impending',
#   'themes',
#   'shifting',
#   'Lim',
#   'Barney',
#   'ex-Yukos',
#   'chased',
#   'Biennial',
#   'Gongga',
#   'hip',
#   'keeps',
#   'athletics',
#   'pigs',
#   'backs',
#   'high-security',
#   'Guggenheim',
#   '20-17',
#   'al-Sheikh',
#   'velvet',
#   'globalization',
#   'Smells',
#   'depressing',
#   'hand-chosen',
#   'inanimate',
#   'touted',
#   'colonize',
#   'Katsuya',
#   'MOSHOESHOE',
#   'ca.',
#   'exhaustion',
#   'day-to-day',
#   'sputtered',
#   'disposing',
#   'universally',
#   'Tekunan',
#   'sit',
#   'Rony',
#   'vaccination',
#   'exaggerated',
#   'GNASSINGBE',
#   'utmost',
#   'cancellations',
#   'regulatory',
#   'Newseum',
#   'marketed',
#   'museums',
#   'rain',
#   'Vancouver',
#   'jute',
#   'second-in-command',
#   'playing',
#   'Jamaicans',
#   'anonymously',
#   'Mardin',
#   'portions',
#   'Prevention',
#   'punishing',
#   'GUELLEH',
#   'injured',
#   'Seppi',
#   '24-year-old',
#   'structures',
#   'shut',
#   'disappearing',
#   'near',
#   'whose',
#   'Arnold',
#   'Taliban-dominated',
#   'jamming',
#   'holidays',
#   'Auwaerter',
#   'insulation',
#   'Tourist',
#   'outlay',
#   'defiance',
#   'vow',
#   'filtering',
#   'el-Sibaie',
#   'newsletter',
#   'football',
#   '61',
#   '38-year-old',
#   'technical',
#   'driven',
#   '1.28.01',
#   'hack',
#   'airborne',
#   'Robin',
#   'Bailey',
#   'Pittsburgh',
#   'Moqtada',
#   'strapping',
#   'mosquitoes',
#   'records',
#   'Chookiat',
#   'unused',
#   'woods',
#   '217',
#   'Tracy',
#   'nationwide',
#   'Stearns',
#   'oncologist',
#   'Issas',
#   'Bodman',
#   'Ruthenians',
#   'impartial',
#   'Ging',
#   'heading',
#   'spurs',
#   'squeeze',
#   'governed',
#   'Nikola',
#   'Newspaper',
#   'Sponsored',
#   'transmitted',
#   'scapegoating',
#   'brightens',
#   'Approaching',
#   'abated',
#   'Dahir',
#   'Clijsters',
#   'Anatol',
#   'Foxy',
#   'Amrullah',
#   'deposed',
#   'inventory',
#   'Olympics',
#   'bare',
#   'incendiary',
#   'personnel',
#   'Michele',
#   '162',
#   'Presse',
#   'Najim',
#   'Sichuan',
#   'Sub-Saharan',
#   'Aleksandar',
#   'aided',
#   'octopus',
#   'Utrecht',
#   'Alderman',
#   'belabored',
#   'contagious',
#   'executed',
#   'disapora',
#   'dries',
#   'storied',
#   'attendance',
#   'Purnomo',
#   'Mussa',
#   'Lawyer',
#   'Timergarah',
#   'follow-up',
#   'earth-moving',
#   'shirt',
#   'roller',
#   'At',
#   'Collemaggio',
#   'Petrobras',
#   'slandered',
#   'hashish',
#   'Tigers',
#   'edge',
#   'Fisherman',
#   'dignitaries',
#   'Caraballo',
#   'enriched',
#   'crept',
#   '1.85',
#   'enrich',
#   'Conn.',
#   'sustains',
#   'mention',
#   'Lisa',
#   '16.2',
#   'renounced',
#   'Amy',
#   '6.2',
#   'Davit',
#   'reopening',
#   'Feldstein',
#   'Astronomers',
#   'supply',
#   'wasteful',
#   'hide-outs',
#   'Potential',
#   'latter',
#   'Catalonia',
#   'scattering',
#   'Hapoalim',
#   'Polska',
#   'bolt',
#   'Legg',
#   'Soviet-imposed',
#   'gleaming',
#   'meter',
#   'Lajcak',
#   'Kapondi',
#   'following',
#   'Ceku',
#   'take-off',
#   'Everado',
#   'Duffy',
#   'Hamadi',
#   'conferences',
#   'Sultan',
#   'Beerenberg',
#   'pork',
#   'Luzhkov',
#   'Pramoni',
#   'Pig',
#   'Self-government',
#   'supervision',
#   'today',
#   'frivolous',
#   'Aboriginal',
#   'Dublin',
#   'eight-year',
#   'grouped',
#   'Moheli',
#   'Buildings',
#   'half-hearted',
#   'heavy',
#   'occured',
#   'far',
#   'Seyoum',
#   'appropriate',
#   'entitled',
#   'stabbed',
#   'exemptions',
#   'Markko',
#   'disarming',
#   'Adelie',
#   'inciting',
#   'Turkish-Iraqi',
#   'Sidakan',
#   'precinct',
#   'practiced',
#   'amid',
#   'Jawad',
#   'Porter',
#   'WINTERTIME',
#   'McCormack',
#   '154th',
#   'booty',
#   'monarch',
#   'repression',
#   'acid',
#   'exacerbating',
#   'incredible',
#   'Implementation',
#   'Microsoft',
#   'chilled',
#   'Ciampino',
#   'Meat',
#   'aiming',
#   'fragmentation',
#   'bulldozing',
#   'green-card',
#   'violation',
#   'Ingushetia',
#   'innovations',
#   'Camel',
#   'remain',
#   'Aiko',
#   'Antonin',
#   'Kalachen',
#   'opponent',
#   'benefits',
#   'seven-year',
#   'Inniger',
#   'observers',
#   'Slovakia',
#   'Scandal',
#   'apt',
#   'Manx',
#   'checked',
#   'bruises',
#   'clamor',
#   'elect',
#   'encourages',
#   'regularly',
#   '35',
#   'psychological',
#   'despondent',
#   'Meza',
#   'blew',
#   'Antonio',
#   'recalling',
#   '1,04,586',
#   'rebel-',
#   'interpreter',
#   '07-Feb',
#   'Cube',
#   'move',
#   'brazen',
#   'Islamiah',
#   'animals',
#   '14-thousand',
#   'poetry',
#   'Zinjibar',
#   '13,543',
#   'Ontario',
#   'trace',
#   'mane',
#   'renting',
#   'Latifiya',
#   'National',
#   'prediction',
#   'Strips',
#   'clipped',
#   'McNuggets',
#   'headquarters',
#   'consolidation',
#   'lease',
#   'two-term',
#   'Monitor',
#   'Bruhin',
#   '70.2',
#   'Yat',
#   'scrambling',
#   'retroactively',
#   'LaRose',
#   'Kennedy',
#   'inroads',
#   'sanctions',
#   'Insider',
#   'Delegate',
#   'humiliating',
#   'chamber',
#   'Tu-160',
#   'hardships',
#   'Mazlan',
#   'pain',
#   'Hafeez',
#   'Crawford',
#   'icy',
#   'now',
#   'Justin',
#   'Ui',
#   'Tearfund',
#   'Departments',
#   'lion',
#   'Arms',
#   'Jalna',
#   'Dastjerdi',
#   'restoring',
#   'Diabetics',
#   'recount',
#   'shallow',
#   'justly',
#   'leaked',
#   'Ongoing',
#   'noting',
#   'scandals',
#   'resort',
#   'sufficiently',
#   'Rafidain',
#   'Generals',
#   'Leah',
#   'Costello',
#   '11-nation',
#   'gloomier',
#   'bombings',
#   'Infrared',
#   '1,15,000',
#   'Saldanha',
#   'Forty-one',
#   '39',
#   'Ambrosio',
#   'Waziriyah',
#   'opinion',
#   'Schoomaker',
#   'healthcare',
#   'al-Zarqwai',
#   'Institutional',
#   'Ahadi',
#   'Honda',
#   'navies',
#   'triggered',
#   'Anup',
#   '1900',
#   'Nargis',
#   'Schneiderhan',
#   'medical',
#   'Shimon',
#   'glades',
#   'straining',
#   'writers',
#   'policy',
#   'Talat',
#   'Hangzhou',
#   'news',
#   '640',
#   'paint',
#   'going',
#   'reacted',
#   '407',
#   'Perth-based',
#   'Celsius',
#   'evaluates',
#   '7-Eleven',
#   'solved',
#   'Jibla',
#   'insurgency-plagued',
#   'villa',
#   'Slovenes',
#   'Colored',
#   'splintered',
#   'expenses',
#   'mastery',
#   'offended',
#   'demise',
#   'Syrian-dominated',
#   'acquire',
#   'Hundreds',
#   'N.C.',
#   'Self-interest',
#   'meaningful',
#   'Dutch-speaking',
#   'AirAsia',
#   'Bag',
#   'casino',
#   'thorn',
#   'tearful',
#   'worshipers',
#   'newly-signed',
#   'solve',
#   'left-of-center',
#   'top-ranked',
#   'quench',
#   'disparate',
#   'BOZIZE',
#   'paralysed',
#   'minimize',
#   'al-Muasher',
#   'AHMADI-NEJAD',
#   'consisted',
#   'crewmembers',
#   'closer',
#   'minke',
#   'Kozloduy',
#   'Musical',
#   'pre-judge',
#   'Frank',
#   'thanking',
#   'accreditation',
#   'wag',
#   'hearty',
#   'tactical',
#   'Anheuser-Busch',
#   'revived',
#   'Aston',
#   '2,38,000',
#   'win-loss',
#   'Kompas',
#   'manger',
#   'services-based',
#   'rabbi',
#   'anyplace',
#   'ransacking',
#   'Challengers',
#   'mistreatment',
#   'Cuban',
#   'Muttahida',
#   'choices',
#   'overstaying',
#   'Hudson',
#   'ex-soldiers',
#   'heaviest',
#   '2,000',
#   'Freezing',
#   'lose',
#   'Sebastian',
#   'Gurage',
#   '14,706',
#   'ideological',
#   'implacable',
#   'small-cell',
#   'Hemingway',
#   'Mohmand',
#   'debt',
#   'Canadian',
#   'Nayef',
#   'Morariu',
#   'Arero',
#   'Alassane',
#   'scorers',
#   'shows',
#   '1896',
#   'midday',
#   'consumes',
#   'duty',
#   '809',
#   'apply',
#   'patronage',
#   'Diamonds',
#   'billionaires',
#   'charged',
#   'Talansky',
#   'Unique',
#   'procedures',
#   'handful',
#   'conspiring',
#   'implicating',
#   'memorabilia',
#   'actively',
#   'searchers',
#   'Baghaichhari',
#   '3.76',
#   'sculptures',
#   'gas-guzzling',
#   'Nixon',
#   'Petrova',
#   'Conditions',
#   'discredited',
#   'multi-billion-dollar',
#   'tolling',
#   'design',
#   '22,000',
#   'Rato',
#   'Proliferation',
#   'optimism',
#   'murmured',
#   'conclude',
#   'jihad',
#   'Pixar',
#   '782',
#   'Qutbi',
#   'penguin',
#   'Jing',
#   '130',
#   'fleets',
#   'Gunsmoke',
#   'Harman',
#   'commanders',
#   'Akhtar',
#   '30-thousand',
#   'archival',
#   'pretax',
#   'Sint',
#   'Mirror',
#   'Western-backed',
#   'Darmawan',
#   'Nano',
#   'Kurdistan',
#   'Calderon',
#   'Leonidas',
#   '101st',
#   'commiserated',
#   'payroll',
#   'pirate-infested',
#   'pm',
#   '43rd-ranked',
#   'subspecies',
#   'Lehman',
#   'dazzling',
#   'waved',
#   'espionage',
#   'Bloom',
#   'liters',
#   'crew',
#   'incompetence',
#   'mend',
#   'ATP',
#   'findings',
#   'Humphreys',
#   'header',
#   'dish',
#   'interrogating',
#   'compensatiion',
#   '275-seat',
#   'Agriculture',
#   'Maysoon',
#   'Ernst',
#   'Saleh',
#   'inventories',
#   'misusing',
#   'rifles',
#   'pews',
#   'quotations',
#   'brewer',
#   'Book',
#   'Ivaylo',
#   'unconcern',
#   'stealing',
#   'colonies',
#   'prowl',
#   'Soaring',
#   'orbital',
#   'knife',
#   'risky',
#   'Toshiyuki',
#   'Uruguay',
#   'Mosques',
#   'Dany',
#   'refloat',
#   'Inspection',
#   '1,000-year',
#   'lenders',
#   'homes',
#   'Msika',
#   'Adumim',
#   'Txeroki',
#   'perhaps',
#   '60-to-36',
#   'greenest',
#   'damper',
#   'possessions',
#   'fundamentalism',
#   'Zettel',
#   'Proceedings',
#   'dismissing',
#   'Raad',
#   'lobbed',
#   'PET',
#   'acclaimed',
#   'short-lived',
#   'utility',
#   'reflect',
#   'Non-Aligned',
#   'Triomphe',
#   'Territorial',
#   'six',
#   'Territory',
#   'proximity',
#   'largest',
#   'cocaine-producing',
#   'roared',
#   'Serious',
#   'Problems',
#   '1885',
#   'battleship',
#   'establishing',
#   'Charm',
#   'Mehmood',
#   'vegetation',
#   'literature',
#   'Corrientes',
#   'unsanctioned',
#   'Forum',
#   'Hilde',
#   'Hamas',
#   'lighthouses',
#   'Wildlife',
#   'nova',
#   'Oberhausen',
#   'Hearing',
#   'DIA',
#   'glasnost',
#   'Teresa',
#   '53rd',
#   'Kiran',
#   'Rain',
#   'Zambia',
#   'Naval',
#   'discharged',
#   'Ottawa',
#   'government-ordered',
#   '39,000',
#   'whipping',
#   'recruited',
#   'anti-piracy',
#   'crowns',
#   '86th',
#   'hostage',
#   'swamp',
#   'explore',
#   'explanations',
#   'Denpasar',
#   'torrential',
#   'Asia-Europe',
#   'hospital',
#   'weigh',
#   'Pin',
#   'Izarra',
#   'Dextre',
#   'Nyunt',
#   'make',
#   'Vy',
#   'multi-million',
#   'arbitrary',
#   'Jaji',
#   'hardcore',
#   'Abel',
#   'OECD',
#   'Dong',
#   '!',
#   'kite',
#   'maltreat',
#   'Hoff',
#   'months-long',
#   'easing',
#   'Lantos',
#   'interaction',
#   'T.',
#   'K-4',
#   'overlooked',
#   'prone',
#   'Gucht',
#   'Successful',
#   'Companies',
#   'Diapers',
#   'apartment',
#   'al-Shahristani',
#   'underreporting',
#   'promarket',
#   'anti-Sikh',
#   'hide',
#   'Fifty',
#   'Sarin',
#   'doled',
#   'jersey',
#   'Dhekelia',
#   'engineered',
#   'Moscow-led',
#   'To',
#   'awake',
#   'intact',
#   'el-Zahraa',
#   'Bududa',
#   'Spokesmen',
#   'Blame',
#   'competes',
#   '228',
#   'Harper',
#   'nice',
#   'Nureddin',
#   'Mwakalyelye',
#   'rediscovery',
#   'Post-ABC',
#   'Kuo',
#   'Naked',
#   'nurtured',
#   'unintended',
#   'fashion',
#   'prosper',
#   'holding',
#   'believed',
#   'inspections',
#   'Notari',
#   'drowning',
#   'air-dropping',
#   'Sideways',
#   'honest',
#   'Troedsson',
#   'rainy',
#   'Ibero-American',
#   'confiscated',
#   'develops',
#   'Repairs',
#   'Glenn',
#   'British-ruled',
#   'linked',
#   'strategically',
#   'escorts',
#   '98,000',
#   'builders',
#   'centre',
#   'Temperatures',
#   'guerillas',
#   'Effah-Apenteng',
#   'Malibu',
#   'Zamfara',
#   'pharaohs',
#   'goodbyes',
#   'Believe',
#   'valleys',
#   'Andar',
#   'Daron',
#   'dehydration',
#   'reaching',
#   'Defectors',
#   'extra',
#   'consecutive',
#   'Cyclone',
#   'merchants',
#   'brings',
#   'Pakistani-Afghan',
#   'Photographer',
#   'staunchest',
#   'out',
#   'assessed',
#   'underage',
#   'Johnny',
#   '1918',
#   'Iraqiya',
#   'wool',
#   'Motors',
#   'pro-THAKSIN',
#   'Paul',
#   'Unicorp',
#   'Budgetary',
#   'natives',
#   'Stopping',
#   'lamb',
#   'Morelos',
#   'Poncet',
#   'curbs',
#   'Armenians',
#   'Stiller',
#   'sulfur',
#   'Gyanendra',
#   'anti-poppy',
#   'Azima',
#   'resting',
#   'Patterson',
#   'Pardons',
#   'suspects',
#   'Al-Mukmin',
#   'Desi',
#   'Iraqi',
#   'Toledo',
#   'terminated',
#   'maintenance',
#   'Trily',
#   'wager',
#   'adapt',
#   'Asad',
#   'Twenty-eight-year-old',
#   'Johannesburg',
#   'Olaf',
#   ...])

# %%
words.append("ENDPAD")
num_words = len(words)
num_words
# Out:
# 35178

# %%
word2idx = create_mappings(words)
word2idx
# Out:
# 35178it [00:00, 1798479.11it/s]
# {'rampage': 1,
#  '405': 2,
#  'pouring': 3,
#  'appear': 4,
#  'Casamance': 5,
#  'incensed': 6,
#  'Alzouma': 7,
#  'Dayton': 8,
#  'snag': 9,
#  'Bernanke': 10,
#  'grounds': 11,
#  'allot': 12,
#  'outperformed': 13,
#  'Xinhua': 14,
#  'boastful': 15,
#  'Sarawak': 16,
#  'estimated': 17,
#  'apprehended': 18,
#  'Pondicherry': 19,
#  'Carreno': 20,
#  'assassins': 21,
#  'exemption': 22,
#  'realizes': 23,
#  'Teir': 24,
#  'Kirkuk': 25,
#  'sketch': 26,
#  'caverns': 27,
#  'Scilingo': 28,
#  'grip': 29,
#  'gridlock': 30,
#  'fatigues': 31,
#  'Salafist': 32,
#  'good-bye': 33,
#  'Sadat': 34,
#  'war-damaged': 35,
#  'involving': 36,
#  'Congressman': 37,
#  'Cleric': 38,
#  'Dalian': 39,
#  'notional': 40,
#  'Anabel': 41,
#  'relied': 42,
#  'tamed': 43,
#  'Dobrynska': 44,
#  'Payne': 45,
#  'behaviour': 46,
#  'go-betweens': 47,
#  'sleeve': 48,
#  'arthritis': 49,
#  'westward': 50,
#  'Blanco': 51,
#  'Saparmurat': 52,
#  'overburdened': 53,
#  'pontificate': 54,
#  'Caspian': 55,
#  'constraints': 56,
#  '170-meter': 57,
#  'Fadilah': 58,
#  'supervising': 59,
#  'Si': 60,
#  'uncontrolled': 61,
#  'wall': 62,
#  'hospitalized': 63,
#  'hotel': 64,
#  'shafts': 65,
#  'Zabul': 66,
#  'deteriorates': 67,
#  'cancers': 68,
#  'Tito': 69,
#  'al-Maliky': 70,
#  'ringleader': 71,
#  'N.J.': 72,
#  'Arabiya': 73,
#  'acceptable': 74,
#  'Scientists': 75,
#  '1648': 76,
#  'darkness': 77,
#  'Tidal': 78,
#  'SAAKASHVILI': 79,
#  'Managing': 80,
#  'Endowment': 81,
#  'al-Watan': 82,
#  'Seibu': 83,
#  'Marghzar': 84,
#  'hyperinflation': 85,
#  'sophisticated': 86,
#  'format': 87,
#  'tall': 88,
#  'Ted': 89,
#  'humiliation': 90,
#  'complicated': 91,
#  'Doetinchem': 92,
#  'Gasquet': 93,
#  'pressures': 94,
#  'Belet': 95,
#  'introduces': 96,
#  'Eduard': 97,
#  'J.P.': 98,
#  'downstream': 99,
#  'Enterprise': 100,
#  'balances': 101,
#  'Préval': 102,
#  'defused': 103,
#  'vocation': 104,
#  'Surkhanpha': 105,
#  'contrasts': 106,
#  'unmanned': 107,
#  'Machinists': 108,
#  'Confessed': 109,
#  'July-August': 110,
#  'hijacking': 111,
#  'reshuffling': 112,
#  'Simone': 113,
#  'materialized': 114,
#  'enemies': 115,
#  'estates': 116,
#  'Christofias': 117,
#  'anti-violence': 118,
#  'leveling': 119,
#  'Danielle': 120,
#  'Goats': 121,
#  'Substantial': 122,
#  'urban': 123,
#  'Alcantara': 124,
#  'Novosti': 125,
#  'Nimroz': 126,
#  'tables': 127,
#  'malnourished': 128,
#  'important': 129,
#  'quarantine': 130,
#  'JVP': 131,
#  'Bears': 132,
#  're-invest': 133,
#  'Rica': 134,
#  'instigating': 135,
#  'Pinas': 136,
#  'occupying': 137,
#  'aragonite': 138,
#  '50th': 139,
#  'military-owned': 140,
#  'Completing': 141,
#  '500-meter': 142,
#  'Bralo': 143,
#  'CPJ': 144,
#  'stemming': 145,
#  'Krasniqi': 146,
#  'strenuously': 147,
#  '300-member': 148,
#  'Yuri': 149,
#  'Novak': 150,
#  'expenditures': 151,
#  'Agim': 152,
#  'Dissostichus': 153,
#  'flames': 154,
#  'Lindsey': 155,
#  'counsel-general': 156,
#  'Maazou': 157,
#  'build-up': 158,
#  'contradicted': 159,
#  'spiral': 160,
#  'domain': 161,
#  'THIEF': 162,
#  'Al-Shihri': 163,
#  '17-month': 164,
#  'Chigwedere': 165,
#  '452': 166,
#  'watchful': 167,
#  '7.30': 168,
#  'jockeys': 169,
#  'labors': 170,
#  'Keraterm': 171,
#  'dioxin': 172,
#  'Seeing': 173,
#  'scholars': 174,
#  'debating': 175,
#  'Golding': 176,
#  'beginning': 177,
#  'asserting': 178,
#  'impending': 179,
#  'themes': 180,
#  'shifting': 181,
#  'Lim': 182,
#  'Barney': 183,
#  'ex-Yukos': 184,
#  'chased': 185,
#  'Biennial': 186,
#  'Gongga': 187,
#  'hip': 188,
#  'keeps': 189,
#  'athletics': 190,
#  'pigs': 191,
#  'backs': 192,
#  'high-security': 193,
#  'Guggenheim': 194,
#  '20-17': 195,
#  'al-Sheikh': 196,
#  'velvet': 197,
#  'globalization': 198,
#  'Smells': 199,
#  'depressing': 200,
#  'hand-chosen': 201,
#  'inanimate': 202,
#  'touted': 203,
#  'colonize': 204,
#  'Katsuya': 205,
#  'MOSHOESHOE': 206,
#  'ca.': 207,
#  'exhaustion': 208,
#  'day-to-day': 209,
#  'sputtered': 210,
#  'disposing': 211,
#  'universally': 212,
#  'Tekunan': 213,
#  'sit': 214,
#  'Rony': 215,
#  'vaccination': 216,
#  'exaggerated': 217,
#  'GNASSINGBE': 218,
#  'utmost': 219,
#  'cancellations': 220,
#  'regulatory': 221,
#  'Newseum': 222,
#  'marketed': 223,
#  'museums': 224,
#  'rain': 225,
#  'Vancouver': 226,
#  'jute': 227,
#  'second-in-command': 228,
#  'playing': 229,
#  'Jamaicans': 230,
#  'anonymously': 231,
#  'Mardin': 232,
#  'portions': 233,
#  'Prevention': 234,
#  'punishing': 235,
#  'GUELLEH': 236,
#  'injured': 237,
#  'Seppi': 238,
#  '24-year-old': 239,
#  'structures': 240,
#  'shut': 241,
#  'disappearing': 242,
#  'near': 243,
#  'whose': 244,
#  'Arnold': 245,
#  'Taliban-dominated': 246,
#  'jamming': 247,
#  'holidays': 248,
#  'Auwaerter': 249,
#  'insulation': 250,
#  'Tourist': 251,
#  'outlay': 252,
#  'defiance': 253,
#  'vow': 254,
#  'filtering': 255,
#  'el-Sibaie': 256,
#  'newsletter': 257,
#  'football': 258,
#  '61': 259,
#  '38-year-old': 260,
#  'technical': 261,
#  'driven': 262,
#  '1.28.01': 263,
#  'hack': 264,
#  'airborne': 265,
#  'Robin': 266,
#  'Bailey': 267,
#  'Pittsburgh': 268,
#  'Moqtada': 269,
#  'strapping': 270,
#  'mosquitoes': 271,
#  'records': 272,
#  'Chookiat': 273,
#  'unused': 274,
#  'woods': 275,
#  '217': 276,
#  'Tracy': 277,
#  'nationwide': 278,
#  'Stearns': 279,
#  'oncologist': 280,
#  'Issas': 281,
#  'Bodman': 282,
#  'Ruthenians': 283,
#  'impartial': 284,
#  'Ging': 285,
#  'heading': 286,
#  'spurs': 287,
#  'squeeze': 288,
#  'governed': 289,
#  'Nikola': 290,
#  'Newspaper': 291,
#  'Sponsored': 292,
#  'transmitted': 293,
#  'scapegoating': 294,
#  'brightens': 295,
#  'Approaching': 296,
#  'abated': 297,
#  'Dahir': 298,
#  'Clijsters': 299,
#  'Anatol': 300,
#  'Foxy': 301,
#  'Amrullah': 302,
#  'deposed': 303,
#  'inventory': 304,
#  'Olympics': 305,
#  'bare': 306,
#  'incendiary': 307,
#  'personnel': 308,
#  'Michele': 309,
#  '162': 310,
#  'Presse': 311,
#  'Najim': 312,
#  'Sichuan': 313,
#  'Sub-Saharan': 314,
#  'Aleksandar': 315,
#  'aided': 316,
#  'octopus': 317,
#  'Utrecht': 318,
#  'Alderman': 319,
#  'belabored': 320,
#  'contagious': 321,
#  'executed': 322,
#  'disapora': 323,
#  'dries': 324,
#  'storied': 325,
#  'attendance': 326,
#  'Purnomo': 327,
#  'Mussa': 328,
#  'Lawyer': 329,
#  'Timergarah': 330,
#  'follow-up': 331,
#  'earth-moving': 332,
#  'shirt': 333,
#  'roller': 334,
#  'At': 335,
#  'Collemaggio': 336,
#  'Petrobras': 337,
#  'slandered': 338,
#  'hashish': 339,
#  'Tigers': 340,
#  'edge': 341,
#  'Fisherman': 342,
#  'dignitaries': 343,
#  'Caraballo': 344,
#  'enriched': 345,
#  'crept': 346,
#  '1.85': 347,
#  'enrich': 348,
#  'Conn.': 349,
#  'sustains': 350,
#  'mention': 351,
#  'Lisa': 352,
#  '16.2': 353,
#  'renounced': 354,
#  'Amy': 355,
#  '6.2': 356,
#  'Davit': 357,
#  'reopening': 358,
#  'Feldstein': 359,
#  'Astronomers': 360,
#  'supply': 361,
#  'wasteful': 362,
#  'hide-outs': 363,
#  'Potential': 364,
#  'latter': 365,
#  'Catalonia': 366,
#  'scattering': 367,
#  'Hapoalim': 368,
#  'Polska': 369,
#  'bolt': 370,
#  'Legg': 371,
#  'Soviet-imposed': 372,
#  'gleaming': 373,
#  'meter': 374,
#  'Lajcak': 375,
#  'Kapondi': 376,
#  'following': 377,
#  'Ceku': 378,
#  'take-off': 379,
#  'Everado': 380,
#  'Duffy': 381,
#  'Hamadi': 382,
#  'conferences': 383,
#  'Sultan': 384,
#  'Beerenberg': 385,
#  'pork': 386,
#  'Luzhkov': 387,
#  'Pramoni': 388,
#  'Pig': 389,
#  'Self-government': 390,
#  'supervision': 391,
#  'today': 392,
#  'frivolous': 393,
#  'Aboriginal': 394,
#  'Dublin': 395,
#  'eight-year': 396,
#  'grouped': 397,
#  'Moheli': 398,
#  'Buildings': 399,
#  'half-hearted': 400,
#  'heavy': 401,
#  'occured': 402,
#  'far': 403,
#  'Seyoum': 404,
#  'appropriate': 405,
#  'entitled': 406,
#  'stabbed': 407,
#  'exemptions': 408,
#  'Markko': 409,
#  'disarming': 410,
#  'Adelie': 411,
#  'inciting': 412,
#  'Turkish-Iraqi': 413,
#  'Sidakan': 414,
#  'precinct': 415,
#  'practiced': 416,
#  'amid': 417,
#  'Jawad': 418,
#  'Porter': 419,
#  'WINTERTIME': 420,
#  'McCormack': 421,
#  '154th': 422,
#  'booty': 423,
#  'monarch': 424,
#  'repression': 425,
#  'acid': 426,
#  'exacerbating': 427,
#  'incredible': 428,
#  'Implementation': 429,
#  'Microsoft': 430,
#  'chilled': 431,
#  'Ciampino': 432,
#  'Meat': 433,
#  'aiming': 434,
#  'fragmentation': 435,
#  'bulldozing': 436,
#  'green-card': 437,
#  'violation': 438,
#  'Ingushetia': 439,
#  'innovations': 440,
#  'Camel': 441,
#  'remain': 442,
#  'Aiko': 443,
#  'Antonin': 444,
#  'Kalachen': 445,
#  'opponent': 446,
#  'benefits': 447,
#  'seven-year': 448,
#  'Inniger': 449,
#  'observers': 450,
#  'Slovakia': 451,
#  'Scandal': 452,
#  'apt': 453,
#  'Manx': 454,
#  'checked': 455,
#  'bruises': 456,
#  'clamor': 457,
#  'elect': 458,
#  'encourages': 459,
#  'regularly': 460,
#  '35': 461,
#  'psychological': 462,
#  'despondent': 463,
#  'Meza': 464,
#  'blew': 465,
#  'Antonio': 466,
#  'recalling': 467,
#  '1,04,586': 468,
#  'rebel-': 469,
#  'interpreter': 470,
#  '07-Feb': 471,
#  'Cube': 472,
#  'move': 473,
#  'brazen': 474,
#  'Islamiah': 475,
#  'animals': 476,
#  '14-thousand': 477,
#  'poetry': 478,
#  'Zinjibar': 479,
#  '13,543': 480,
#  'Ontario': 481,
#  'trace': 482,
#  'mane': 483,
#  'renting': 484,
#  'Latifiya': 485,
#  'National': 486,
#  'prediction': 487,
#  'Strips': 488,
#  'clipped': 489,
#  'McNuggets': 490,
#  'headquarters': 491,
#  'consolidation': 492,
#  'lease': 493,
#  'two-term': 494,
#  'Monitor': 495,
#  'Bruhin': 496,
#  '70.2': 497,
#  'Yat': 498,
#  'scrambling': 499,
#  'retroactively': 500,
#  'LaRose': 501,
#  'Kennedy': 502,
#  'inroads': 503,
#  'sanctions': 504,
#  'Insider': 505,
#  'Delegate': 506,
#  'humiliating': 507,
#  'chamber': 508,
#  'Tu-160': 509,
#  'hardships': 510,
#  'Mazlan': 511,
#  'pain': 512,
#  'Hafeez': 513,
#  'Crawford': 514,
#  'icy': 515,
#  'now': 516,
#  'Justin': 517,
#  'Ui': 518,
#  'Tearfund': 519,
#  'Departments': 520,
#  'lion': 521,
#  'Arms': 522,
#  'Jalna': 523,
#  'Dastjerdi': 524,
#  'restoring': 525,
#  'Diabetics': 526,
#  'recount': 527,
#  'shallow': 528,
#  'justly': 529,
#  'leaked': 530,
#  'Ongoing': 531,
#  'noting': 532,
#  'scandals': 533,
#  'resort': 534,
#  'sufficiently': 535,
#  'Rafidain': 536,
#  'Generals': 537,
#  'Leah': 538,
#  'Costello': 539,
#  '11-nation': 540,
#  'gloomier': 541,
#  'bombings': 542,
#  'Infrared': 543,
#  '1,15,000': 544,
#  'Saldanha': 545,
#  'Forty-one': 546,
#  '39': 547,
#  'Ambrosio': 548,
#  'Waziriyah': 549,
#  'opinion': 550,
#  'Schoomaker': 551,
#  'healthcare': 552,
#  'al-Zarqwai': 553,
#  'Institutional': 554,
#  'Ahadi': 555,
#  'Honda': 556,
#  'navies': 557,
#  'triggered': 558,
#  'Anup': 559,
#  '1900': 560,
#  'Nargis': 561,
#  'Schneiderhan': 562,
#  'medical': 563,
#  'Shimon': 564,
#  'glades': 565,
#  'straining': 566,
#  'writers': 567,
#  'policy': 568,
#  'Talat': 569,
#  'Hangzhou': 570,
#  'news': 571,
#  '640': 572,
#  'paint': 573,
#  'going': 574,
#  'reacted': 575,
#  '407': 576,
#  'Perth-based': 577,
#  'Celsius': 578,
#  'evaluates': 579,
#  '7-Eleven': 580,
#  'solved': 581,
#  'Jibla': 582,
#  'insurgency-plagued': 583,
#  'villa': 584,
#  'Slovenes': 585,
#  'Colored': 586,
#  'splintered': 587,
#  'expenses': 588,
#  'mastery': 589,
#  'offended': 590,
#  'demise': 591,
#  'Syrian-dominated': 592,
#  'acquire': 593,
#  'Hundreds': 594,
#  'N.C.': 595,
#  'Self-interest': 596,
#  'meaningful': 597,
#  'Dutch-speaking': 598,
#  'AirAsia': 599,
#  'Bag': 600,
#  'casino': 601,
#  'thorn': 602,
#  'tearful': 603,
#  'worshipers': 604,
#  'newly-signed': 605,
#  'solve': 606,
#  'left-of-center': 607,
#  'top-ranked': 608,
#  'quench': 609,
#  'disparate': 610,
#  'BOZIZE': 611,
#  'paralysed': 612,
#  'minimize': 613,
#  'al-Muasher': 614,
#  'AHMADI-NEJAD': 615,
#  'consisted': 616,
#  'crewmembers': 617,
#  'closer': 618,
#  'minke': 619,
#  'Kozloduy': 620,
#  'Musical': 621,
#  'pre-judge': 622,
#  'Frank': 623,
#  'thanking': 624,
#  'accreditation': 625,
#  'wag': 626,
#  'hearty': 627,
#  'tactical': 628,
#  'Anheuser-Busch': 629,
#  'revived': 630,
#  'Aston': 631,
#  '2,38,000': 632,
#  'win-loss': 633,
#  'Kompas': 634,
#  'manger': 635,
#  'services-based': 636,
#  'rabbi': 637,
#  'anyplace': 638,
#  'ransacking': 639,
#  'Challengers': 640,
#  'mistreatment': 641,
#  'Cuban': 642,
#  'Muttahida': 643,
#  'choices': 644,
#  'overstaying': 645,
#  'Hudson': 646,
#  'ex-soldiers': 647,
#  'heaviest': 648,
#  '2,000': 649,
#  'Freezing': 650,
#  'lose': 651,
#  'Sebastian': 652,
#  'Gurage': 653,
#  '14,706': 654,
#  'ideological': 655,
#  'implacable': 656,
#  'small-cell': 657,
#  'Hemingway': 658,
#  'Mohmand': 659,
#  'debt': 660,
#  'Canadian': 661,
#  'Nayef': 662,
#  'Morariu': 663,
#  'Arero': 664,
#  'Alassane': 665,
#  'scorers': 666,
#  'shows': 667,
#  '1896': 668,
#  'midday': 669,
#  'consumes': 670,
#  'duty': 671,
#  '809': 672,
#  'apply': 673,
#  'patronage': 674,
#  'Diamonds': 675,
#  'billionaires': 676,
#  'charged': 677,
#  'Talansky': 678,
#  'Unique': 679,
#  'procedures': 680,
#  'handful': 681,
#  'conspiring': 682,
#  'implicating': 683,
#  'memorabilia': 684,
#  'actively': 685,
#  'searchers': 686,
#  'Baghaichhari': 687,
#  '3.76': 688,
#  'sculptures': 689,
#  'gas-guzzling': 690,
#  'Nixon': 691,
#  'Petrova': 692,
#  'Conditions': 693,
#  'discredited': 694,
#  'multi-billion-dollar': 695,
#  'tolling': 696,
#  'design': 697,
#  '22,000': 698,
#  'Rato': 699,
#  'Proliferation': 700,
#  'optimism': 701,
#  'murmured': 702,
#  'conclude': 703,
#  'jihad': 704,
#  'Pixar': 705,
#  '782': 706,
#  'Qutbi': 707,
#  'penguin': 708,
#  'Jing': 709,
#  '130': 710,
#  'fleets': 711,
#  'Gunsmoke': 712,
#  'Harman': 713,
#  'commanders': 714,
#  'Akhtar': 715,
#  '30-thousand': 716,
#  'archival': 717,
#  'pretax': 718,
#  'Sint': 719,
#  'Mirror': 720,
#  'Western-backed': 721,
#  'Darmawan': 722,
#  'Nano': 723,
#  'Kurdistan': 724,
#  'Calderon': 725,
#  'Leonidas': 726,
#  '101st': 727,
#  'commiserated': 728,
#  'payroll': 729,
#  'pirate-infested': 730,
#  'pm': 731,
#  '43rd-ranked': 732,
#  'subspecies': 733,
#  'Lehman': 734,
#  'dazzling': 735,
#  'waved': 736,
#  'espionage': 737,
#  'Bloom': 738,
#  'liters': 739,
#  'crew': 740,
#  'incompetence': 741,
#  'mend': 742,
#  'ATP': 743,
#  'findings': 744,
#  'Humphreys': 745,
#  'header': 746,
#  'dish': 747,
#  'interrogating': 748,
#  'compensatiion': 749,
#  '275-seat': 750,
#  'Agriculture': 751,
#  'Maysoon': 752,
#  'Ernst': 753,
#  'Saleh': 754,
#  'inventories': 755,
#  'misusing': 756,
#  'rifles': 757,
#  'pews': 758,
#  'quotations': 759,
#  'brewer': 760,
#  'Book': 761,
#  'Ivaylo': 762,
#  'unconcern': 763,
#  'stealing': 764,
#  'colonies': 765,
#  'prowl': 766,
#  'Soaring': 767,
#  'orbital': 768,
#  'knife': 769,
#  'risky': 770,
#  'Toshiyuki': 771,
#  'Uruguay': 772,
#  'Mosques': 773,
#  'Dany': 774,
#  'refloat': 775,
#  'Inspection': 776,
#  '1,000-year': 777,
#  'lenders': 778,
#  'homes': 779,
#  'Msika': 780,
#  'Adumim': 781,
#  'Txeroki': 782,
#  'perhaps': 783,
#  '60-to-36': 784,
#  'greenest': 785,
#  'damper': 786,
#  'possessions': 787,
#  'fundamentalism': 788,
#  'Zettel': 789,
#  'Proceedings': 790,
#  'dismissing': 791,
#  'Raad': 792,
#  'lobbed': 793,
#  'PET': 794,
#  'acclaimed': 795,
#  'short-lived': 796,
#  'utility': 797,
#  'reflect': 798,
#  'Non-Aligned': 799,
#  'Triomphe': 800,
#  'Territorial': 801,
#  'six': 802,
#  'Territory': 803,
#  'proximity': 804,
#  'largest': 805,
#  'cocaine-producing': 806,
#  'roared': 807,
#  'Serious': 808,
#  'Problems': 809,
#  '1885': 810,
#  'battleship': 811,
#  'establishing': 812,
#  'Charm': 813,
#  'Mehmood': 814,
#  'vegetation': 815,
#  'literature': 816,
#  'Corrientes': 817,
#  'unsanctioned': 818,
#  'Forum': 819,
#  'Hilde': 820,
#  'Hamas': 821,
#  'lighthouses': 822,
#  'Wildlife': 823,
#  'nova': 824,
#  'Oberhausen': 825,
#  'Hearing': 826,
#  'DIA': 827,
#  'glasnost': 828,
#  'Teresa': 829,
#  '53rd': 830,
#  'Kiran': 831,
#  'Rain': 832,
#  'Zambia': 833,
#  'Naval': 834,
#  'discharged': 835,
#  'Ottawa': 836,
#  'government-ordered': 837,
#  '39,000': 838,
#  'whipping': 839,
#  'recruited': 840,
#  'anti-piracy': 841,
#  'crowns': 842,
#  '86th': 843,
#  'hostage': 844,
#  'swamp': 845,
#  'explore': 846,
#  'explanations': 847,
#  'Denpasar': 848,
#  'torrential': 849,
#  'Asia-Europe': 850,
#  'hospital': 851,
#  'weigh': 852,
#  'Pin': 853,
#  'Izarra': 854,
#  'Dextre': 855,
#  'Nyunt': 856,
#  'make': 857,
#  'Vy': 858,
#  'multi-million': 859,
#  'arbitrary': 860,
#  'Jaji': 861,
#  'hardcore': 862,
#  'Abel': 863,
#  'OECD': 864,
#  'Dong': 865,
#  '!': 866,
#  'kite': 867,
#  'maltreat': 868,
#  'Hoff': 869,
#  'months-long': 870,
#  'easing': 871,
#  'Lantos': 872,
#  'interaction': 873,
#  'T.': 874,
#  'K-4': 875,
#  'overlooked': 876,
#  'prone': 877,
#  'Gucht': 878,
#  'Successful': 879,
#  'Companies': 880,
#  'Diapers': 881,
#  'apartment': 882,
#  'al-Shahristani': 883,
#  'underreporting': 884,
#  'promarket': 885,
#  'anti-Sikh': 886,
#  'hide': 887,
#  'Fifty': 888,
#  'Sarin': 889,
#  'doled': 890,
#  'jersey': 891,
#  'Dhekelia': 892,
#  'engineered': 893,
#  'Moscow-led': 894,
#  'To': 895,
#  'awake': 896,
#  'intact': 897,
#  'el-Zahraa': 898,
#  'Bududa': 899,
#  'Spokesmen': 900,
#  'Blame': 901,
#  'competes': 902,
#  '228': 903,
#  'Harper': 904,
#  'nice': 905,
#  'Nureddin': 906,
#  'Mwakalyelye': 907,
#  'rediscovery': 908,
#  'Post-ABC': 909,
#  'Kuo': 910,
#  'Naked': 911,
#  'nurtured': 912,
#  'unintended': 913,
#  'fashion': 914,
#  'prosper': 915,
#  'holding': 916,
#  'believed': 917,
#  'inspections': 918,
#  'Notari': 919,
#  'drowning': 920,
#  'air-dropping': 921,
#  'Sideways': 922,
#  'honest': 923,
#  'Troedsson': 924,
#  'rainy': 925,
#  'Ibero-American': 926,
#  'confiscated': 927,
#  'develops': 928,
#  'Repairs': 929,
#  'Glenn': 930,
#  'British-ruled': 931,
#  'linked': 932,
#  'strategically': 933,
#  'escorts': 934,
#  '98,000': 935,
#  'builders': 936,
#  'centre': 937,
#  'Temperatures': 938,
#  'guerillas': 939,
#  'Effah-Apenteng': 940,
#  'Malibu': 941,
#  'Zamfara': 942,
#  'pharaohs': 943,
#  'goodbyes': 944,
#  'Believe': 945,
#  'valleys': 946,
#  'Andar': 947,
#  'Daron': 948,
#  'dehydration': 949,
#  'reaching': 950,
#  'Defectors': 951,
#  'extra': 952,
#  'consecutive': 953,
#  'Cyclone': 954,
#  'merchants': 955,
#  'brings': 956,
#  'Pakistani-Afghan': 957,
#  'Photographer': 958,
#  'staunchest': 959,
#  'out': 960,
#  'assessed': 961,
#  'underage': 962,
#  'Johnny': 963,
#  '1918': 964,
#  'Iraqiya': 965,
#  'wool': 966,
#  'Motors': 967,
#  'pro-THAKSIN': 968,
#  'Paul': 969,
#  'Unicorp': 970,
#  'Budgetary': 971,
#  'natives': 972,
#  'Stopping': 973,
#  'lamb': 974,
#  'Morelos': 975,
#  'Poncet': 976,
#  'curbs': 977,
#  'Armenians': 978,
#  'Stiller': 979,
#  'sulfur': 980,
#  'Gyanendra': 981,
#  'anti-poppy': 982,
#  'Azima': 983,
#  'resting': 984,
#  'Patterson': 985,
#  'Pardons': 986,
#  'suspects': 987,
#  'Al-Mukmin': 988,
#  'Desi': 989,
#  'Iraqi': 990,
#  'Toledo': 991,
#  'terminated': 992,
#  'maintenance': 993,
#  'Trily': 994,
#  'wager': 995,
#  'adapt': 996,
#  'Asad': 997,
#  'Twenty-eight-year-old': 998,
#  'Johannesburg': 999,
#  'Olaf': 1000,
#  ...}

# %%
num_ner_tags, ner_tags = get_stats(data, "NER Tag")
num_ner_tags, ner_tags
# Out:
# Unique NER Tag in corpus: 18
# (17,
#  ['B-geo',
#   'I-tim',
#   'B-eve',
#   'I-gpe',
#   'I-geo',
#   'I-art',
#   'O',
#   'I-eve',
#   'B-org',
#   'B-art',
#   'I-nat',
#   'B-tim',
#   'I-org',
#   'B-per',
#   'B-nat',
#   'B-gpe',
#   'I-per'])

# %%
tag2idx = create_mappings(ner_tags)
tag2idx
# Out:
# 17it [00:00, 236103.21it/s]
# {'B-geo': 1,
#  'I-tim': 2,
#  'B-eve': 3,
#  'I-gpe': 4,
#  'I-geo': 5,
#  'I-art': 6,
#  'O': 7,
#  'I-eve': 8,
#  'B-org': 9,
#  'B-art': 10,
#  'I-nat': 11,
#  'B-tim': 12,
#  'I-org': 13,
#  'B-per': 14,
#  'B-nat': 15,
#  'B-gpe': 16,
#  'I-per': 17}

# %%
def sentence_integrate(df: pd.DataFrame, sentence_col_name: str, word_col_name: str, ner_col_name: str):
    """Map word within the sentence to the associated ner tag
    
    Parameters
    ----------
    df: `pd.DataFrame`
        DataFrame containing sentences with consecutive indices and starting with "Index" = 1
    sentence_col_name
    word_col_name
    ner_col_name

    Returns
    -------
    sentences: `list`
        2D list [# sentences, pairing ((word, ner tag))]
    """
    sentences = []
    sentence_info = []

    for _, row in tqdm(df.iterrows(), total=len(df), desc="Processing Sentences"):
        if row[sentence_col_name] == 1:
            if len(sentence_info) > 0:  # If there are words in the sentence
                sentences.append(sentence_info)

                sentence_info = []  # Reset for the next sentence
            
        word = row[word_col_name]
        ner_tag = row[ner_col_name]
        sentence_info.append((word, ner_tag))
        
    # Process the last sentence
    if sentence_info:
        sentences.append(sentence_info)

    return sentences

# %%
new_sentence_col_name = 'New Sentence Index'
word_col_name = 'Word'
ner_tag_col_name = 'NER Tag'
sentences = sentence_integrate(data, new_sentence_col_name, word_col_name, ner_tag_col_name)
# Out:
# Processing Sentences:   0%|          | 0/1096533 [00:00<?, ?it/s]
# Processing Sentences: 100%|██████████| 1096533/1096533 [00:47<00:00, 23133.92it/s]

# %%
len(sentences)
# Out:
# 47959

# %%
sentences
# Out:
# [[('Thousands', 'O'),
#   ('of', 'O'),
#   ('demonstrators', 'O'),
#   ('have', 'O'),
#   ('marched', 'O'),
#   ('through', 'O'),
#   ('London', 'B-geo'),
#   ('to', 'O'),
#   ('protest', 'O'),
#   ('the', 'O'),
#   ('war', 'O'),
#   ('in', 'O'),
#   ('Iraq', 'B-geo'),
#   ('and', 'O'),
#   ('demand', 'O'),
#   ('the', 'O'),
#   ('withdrawal', 'O'),
#   ('of', 'O'),
#   ('British', 'B-gpe'),
#   ('troops', 'O'),
#   ('from', 'O'),
#   ('that', 'O'),
#   ('country', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Families', 'O'),
#   ('of', 'O'),
#   ('soldiers', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('conflict', 'O'),
#   ('joined', 'O'),
#   ('the', 'O'),
#   ('protesters', 'O'),
#   ('who', 'O'),
#   ('carried', 'O'),
#   ('banners', 'O'),
#   ('with', 'O'),
#   ('such', 'O'),
#   ('slogans', 'O'),
#   ('as', 'O'),
#   ('"', 'O'),
#   ('Bush', 'B-per'),
#   ('Number', 'O'),
#   ('One', 'O'),
#   ('Terrorist', 'O'),
#   ('"', 'O'),
#   ('and', 'O'),
#   ('"', 'O'),
#   ('Stop', 'O'),
#   ('the', 'O'),
#   ('Bombings', 'O'),
#   ('.', 'O'),
#   ('"', 'O'),
#   ('', '')],
#  [('They', 'O'),
#   ('marched', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('Houses', 'O'),
#   ('of', 'O'),
#   ('Parliament', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('rally', 'O'),
#   ('in', 'O'),
#   ('Hyde', 'B-geo'),
#   ('Park', 'I-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Police', 'O'),
#   ('put', 'O'),
#   ('the', 'O'),
#   ('number', 'O'),
#   ('of', 'O'),
#   ('marchers', 'O'),
#   ('at', 'O'),
#   ('10,000', 'O'),
#   ('while', 'O'),
#   ('organizers', 'O'),
#   ('claimed', 'O'),
#   ('it', 'O'),
#   ('was', 'O'),
#   ('1,00,000', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('protest', 'O'),
#   ('comes', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('eve', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('annual', 'O'),
#   ('conference', 'O'),
#   ('of', 'O'),
#   ('Britain', 'B-geo'),
#   ("'s", 'O'),
#   ('ruling', 'O'),
#   ('Labor', 'B-org'),
#   ('Party', 'I-org'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('southern', 'O'),
#   ('English', 'B-gpe'),
#   ('seaside', 'O'),
#   ('resort', 'O'),
#   ('of', 'O'),
#   ('Brighton', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('party', 'O'),
#   ('is', 'O'),
#   ('divided', 'O'),
#   ('over', 'O'),
#   ('Britain', 'B-gpe'),
#   ("'s", 'O'),
#   ('participation', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Iraq', 'B-geo'),
#   ('conflict', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('continued', 'O'),
#   ('deployment', 'O'),
#   ('of', 'O'),
#   ('8,500', 'O'),
#   ('British', 'B-gpe'),
#   ('troops', 'O'),
#   ('in', 'O'),
#   ('that', 'O'),
#   ('country', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('London', 'B-geo'),
#   ('march', 'O'),
#   ('came', 'O'),
#   ('ahead', 'O'),
#   ('of', 'O'),
#   ('anti-war', 'O'),
#   ('protests', 'O'),
#   ('today', 'O'),
#   ('in', 'O'),
#   ('other', 'O'),
#   ('cities', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('Rome', 'B-geo'),
#   (',', 'O'),
#   ('Paris', 'B-geo'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('Madrid', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('International', 'B-org'),
#   ('Atomic', 'I-org'),
#   ('Energy', 'I-org'),
#   ('Agency', 'I-org'),
#   ('is', 'O'),
#   ('to', 'O'),
#   ('hold', 'O'),
#   ('second', 'O'),
#   ('day', 'O'),
#   ('of', 'O'),
#   ('talks', 'O'),
#   ('in', 'O'),
#   ('Vienna', 'B-geo'),
#   ('Wednesday', 'B-tim'),
#   ('on', 'O'),
#   ('how', 'O'),
#   ('to', 'O'),
#   ('respond', 'O'),
#   ('to', 'O'),
#   ('Iran', 'B-gpe'),
#   ("'s", 'O'),
#   ('resumption', 'O'),
#   ('of', 'O'),
#   ('low-level', 'O'),
#   ('uranium', 'O'),
#   ('conversion', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Iran', 'B-gpe'),
#   ('this', 'O'),
#   ('week', 'O'),
#   ('restarted', 'O'),
#   ('parts', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('conversion', 'O'),
#   ('process', 'O'),
#   ('at', 'O'),
#   ('its', 'O'),
#   ('Isfahan', 'B-geo'),
#   ('nuclear', 'O'),
#   ('plant', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Iranian', 'B-gpe'),
#   ('officials', 'O'),
#   ('say', 'O'),
#   ('they', 'O'),
#   ('expect', 'O'),
#   ('to', 'O'),
#   ('get', 'O'),
#   ('access', 'O'),
#   ('to', 'O'),
#   ('sealed', 'O'),
#   ('sensitive', 'O'),
#   ('parts', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('plant', 'O'),
#   ('Wednesday', 'B-tim'),
#   (',', 'O'),
#   ('after', 'O'),
#   ('an', 'O'),
#   ('IAEA', 'B-org'),
#   ('surveillance', 'O'),
#   ('system', 'O'),
#   ('begins', 'O'),
#   ('functioning', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('step', 'O'),
#   ('will', 'O'),
#   ('allow', 'O'),
#   ('the', 'O'),
#   ('facility', 'O'),
#   ('to', 'O'),
#   ('operate', 'O'),
#   ('at', 'O'),
#   ('full', 'O'),
#   ('capacity', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('European', 'B-org'),
#   ('Union', 'I-org'),
#   (',', 'O'),
#   ('with', 'O'),
#   ('U.S.', 'B-gpe'),
#   ('backing', 'O'),
#   (',', 'O'),
#   ('has', 'O'),
#   ('threatened', 'O'),
#   ('to', 'O'),
#   ('refer', 'O'),
#   ('Iran', 'B-gpe'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('U.N.', 'B-org'),
#   ('Security', 'I-org'),
#   ('Council', 'I-org'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('could', 'O'),
#   ('impose', 'O'),
#   ('sanctions', 'O'),
#   ('if', 'O'),
#   ('it', 'O'),
#   ('finds', 'O'),
#   ('Tehran', 'B-gpe'),
#   ('has', 'O'),
#   ('violated', 'O'),
#   ('the', 'O'),
#   ('Nuclear', 'B-art'),
#   ('Non-Proliferation', 'I-art'),
#   ('treaty', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Iran', 'B-gpe'),
#   ("'s", 'O'),
#   ('new', 'O'),
#   ('President', 'B-per'),
#   ('Mahmoud', 'I-per'),
#   ('Ahmadinejad', 'I-per'),
#   ('said', 'O'),
#   ('Tuesday', 'B-tim'),
#   ('that', 'O'),
#   ('European', 'B-gpe'),
#   ('incentives', 'O'),
#   ('aimed', 'O'),
#   ('at', 'O'),
#   ('persuading', 'O'),
#   ('Iran', 'B-gpe'),
#   ('to', 'O'),
#   ('end', 'O'),
#   ('its', 'O'),
#   ('nuclear', 'O'),
#   ('fuel', 'O'),
#   ('program', 'O'),
#   ('are', 'O'),
#   ('an', 'O'),
#   ('insult', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('Iranian', 'B-gpe'),
#   ('nation', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Two', 'O'),
#   ('Germans', 'B-gpe'),
#   ('and', 'O'),
#   ('four', 'O'),
#   ('Nigerian', 'B-gpe'),
#   ('oil', 'O'),
#   ('workers', 'O'),
#   ('were', 'O'),
#   ('kidnapped', 'O'),
#   ('by', 'O'),
#   ('armed', 'O'),
#   ('militants', 'O'),
#   ('during', 'O'),
#   ('a', 'O'),
#   ('raid', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('boat', 'O'),
#   ('in', 'O'),
#   ('Nigeria', 'B-geo'),
#   ("'s", 'O'),
#   ('southern', 'O'),
#   ('oil-rich', 'O'),
#   ('Delta', 'B-geo'),
#   ('region', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('An', 'O'),
#   ('official', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('German', 'B-gpe'),
#   ('firm', 'O'),
#   ('Bilfinger', 'B-org'),
#   ('Berger', 'I-org'),
#   (',', 'O'),
#   ('Thomas', 'B-per'),
#   ('Horbach', 'I-per'),
#   (',', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('gunmen', 'O'),
#   ('stopped', 'O'),
#   ('the', 'O'),
#   ('supply', 'O'),
#   ('boat', 'O'),
#   ('Wednesday', 'B-tim'),
#   ('as', 'O'),
#   ('it', 'O'),
#   ('sailed', 'O'),
#   ('from', 'O'),
#   ('Delta', 'B-geo'),
#   ('State', 'I-geo'),
#   ('to', 'O'),
#   ('Bayelsa', 'B-geo'),
#   ('State', 'I-geo'),
#   ('to', 'O'),
#   ('inspect', 'O'),
#   ('an', 'O'),
#   ('offshore', 'O'),
#   ('oil', 'O'),
#   ('field', 'O'),
#   ('owned', 'O'),
#   ('by', 'O'),
#   ('Royal-Dutch', 'B-org'),
#   ('Shell', 'I-org'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('German', 'B-gpe'),
#   ('firm', 'O'),
#   ('works', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('sub-contractor', 'O'),
#   ('for', 'O'),
#   ('Shell', 'B-org'),
#   ('.', 'O'),
#   ('', '')],
#  [('Militant', 'O'),
#   ('groups', 'O'),
#   ('frequently', 'O'),
#   ('attack', 'O'),
#   ('oil', 'O'),
#   ('operations', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Niger', 'B-geo'),
#   ('Delta', 'I-geo'),
#   ('to', 'O'),
#   ('demand', 'O'),
#   ('social', 'O'),
#   ('services', 'O'),
#   ('and', 'O'),
#   ('better', 'O'),
#   ('job', 'O'),
#   ('opportunities', 'O'),
#   ('from', 'O'),
#   ('multinational', 'O'),
#   ('companies', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Poor', 'O'),
#   ('residents', 'O'),
#   ('often', 'O'),
#   ('complain', 'O'),
#   ('they', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('cheated', 'O'),
#   ('out', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('huge', 'O'),
#   ('riches', 'O'),
#   ('extracted', 'O'),
#   ('from', 'O'),
#   ('their', 'O'),
#   ('tribal', 'O'),
#   ('lands', 'O'),
#   ('-', 'O'),
#   ('where', 'O'),
#   ('the', 'O'),
#   ('bulk', 'O'),
#   ('of', 'O'),
#   ('Nigeria', 'B-gpe'),
#   ("'s", 'O'),
#   ('2.3', 'O'),
#   ('million', 'O'),
#   ('barrels', 'O'),
#   ('of', 'O'),
#   ('petroleum', 'O'),
#   ('are', 'O'),
#   ('pumped', 'O'),
#   ('daily', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Suspected', 'O'),
#   ('Islamist', 'O'),
#   ('rebels', 'O'),
#   ('have', 'O'),
#   ('fired', 'O'),
#   ('mortar', 'O'),
#   ('shells', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('palace', 'O'),
#   ('used', 'O'),
#   ('by', 'O'),
#   ('Somalia', 'B-geo'),
#   ("'s", 'O'),
#   ('interim', 'O'),
#   ('President', 'B-per'),
#   ('Abdullahi', 'I-per'),
#   ('Yusuf', 'I-per'),
#   ('Ahmad', 'I-per'),
#   ('.', 'O'),
#   ('', '')],
#  [('It', 'O'),
#   ('was', 'O'),
#   ('not', 'O'),
#   ('immediately', 'O'),
#   ('clear', 'O'),
#   ('if', 'O'),
#   ('the', 'O'),
#   ('president', 'O'),
#   ('was', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('palace', 'O'),
#   ('in', 'O'),
#   ('Mogadishu', 'B-geo'),
#   ('when', 'O'),
#   ('the', 'O'),
#   ('attack', 'O'),
#   ('occurred', 'O'),
#   ('or', 'O'),
#   ('if', 'O'),
#   ('anyone', 'O'),
#   ('was', 'O'),
#   ('hurt', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Local', 'O'),
#   ('news', 'O'),
#   ('reports', 'O'),
#   ('said', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('five', 'O'),
#   ('mortar', 'O'),
#   ('shells', 'O'),
#   ('hit', 'O'),
#   ('the', 'O'),
#   ('palace', 'O'),
#   ('compound', 'O'),
#   ('and', 'O'),
#   ('other', 'O'),
#   ('mortars', 'O'),
#   ('were', 'O'),
#   ('fired', 'O'),
#   ('elsewhere', 'O'),
#   ('in', 'O'),
#   ('Mogadishu', 'B-geo'),
#   ('Wednesday', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('attacks', 'O'),
#   ('occurred', 'O'),
#   ('after', 'O'),
#   ('the', 'O'),
#   ('government', 'O'),
#   ('said', 'O'),
#   ('it', 'O'),
#   ('will', 'O'),
#   ('go', 'O'),
#   ('ahead', 'O'),
#   ('with', 'O'),
#   ('a', 'O'),
#   ('reconciliation', 'O'),
#   ('conference', 'O'),
#   ('to', 'O'),
#   ('which', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('1,300', 'O'),
#   ('Somali', 'B-gpe'),
#   ('elders', 'O'),
#   (',', 'O'),
#   ('warlords', 'O'),
#   ('and', 'O'),
#   ('politicians', 'O'),
#   ('are', 'O'),
#   ('invited', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Iraqi', 'B-gpe'),
#   ('military', 'O'),
#   ('officials', 'O'),
#   ('say', 'O'),
#   ('tanks', 'O'),
#   ('and', 'O'),
#   ('troops', 'O'),
#   ('have', 'O'),
#   ('arrived', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('northern', 'O'),
#   ('city', 'O'),
#   ('Mosul', 'B-geo'),
#   ('for', 'O'),
#   ('a', 'O'),
#   ('new', 'O'),
#   ('offensive', 'O'),
#   ('against', 'O'),
#   ('al', 'B-org'),
#   ('Qaida', 'I-org'),
#   ('in', 'I-org'),
#   ('Iraq', 'I-org'),
#   ('fighters', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Officials', 'O'),
#   ('will', 'O'),
#   ('not', 'O'),
#   ('say', 'O'),
#   ('how', 'O'),
#   ('many', 'O'),
#   ('troops', 'O'),
#   ('have', 'O'),
#   ('arrived', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Sunni', 'B-geo'),
#   ('Arab', 'I-geo'),
#   ('and', 'O'),
#   ('Kurdish', 'B-geo'),
#   ('city', 'O'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('bombings', 'O'),
#   ('last', 'O'),
#   ('week', 'O'),
#   ('killed', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('34', 'O'),
#   ('people', 'O'),
#   ('and', 'O'),
#   ('wounded', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('200', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('U.S.', 'B-gpe'),
#   ('commanders', 'O'),
#   ('have', 'O'),
#   ('not', 'O'),
#   ('explained', 'O'),
#   ('how', 'O'),
#   ('American', 'B-gpe'),
#   ('forces', 'O'),
#   ('will', 'O'),
#   ('participate', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('offensive', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Officials', 'O'),
#   ('say', 'O'),
#   ('al', 'B-org'),
#   ('Qaida', 'I-org'),
#   ('in', 'I-org'),
#   ('Iraq', 'I-org'),
#   ('fighters', 'O'),
#   ('have', 'O'),
#   ('fled', 'O'),
#   ('successful', 'O'),
#   ('campaigns', 'O'),
#   ('against', 'O'),
#   ('them', 'O'),
#   ('in', 'O'),
#   ('Anbar', 'B-geo'),
#   ('province', 'O'),
#   ('and', 'O'),
#   ('Baghdad', 'B-geo'),
#   ('to', 'O'),
#   ('other', 'O'),
#   ('northern', 'O'),
#   ('provinces', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Mosul', 'B-geo'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('largest', 'O'),
#   ('city', 'O'),
#   ('north', 'O'),
#   ('of', 'O'),
#   ('Baghdad', 'B-geo'),
#   ('and', 'O'),
#   ('has', 'O'),
#   ('long', 'O'),
#   ('been', 'O'),
#   ('a', 'O'),
#   ('stronghold', 'O'),
#   ('of', 'O'),
#   ('Sunni', 'B-org'),
#   ('militant', 'O'),
#   ('fighters', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('In', 'O'),
#   ('other', 'O'),
#   ('violence', 'O'),
#   (',', 'O'),
#   ('U.S.', 'B-gpe'),
#   ('officials', 'O'),
#   ('said', 'O'),
#   ('one', 'O'),
#   ('American', 'B-gpe'),
#   ('soldier', 'O'),
#   ('was', 'O'),
#   ('killed', 'O'),
#   ('while', 'O'),
#   ('on', 'O'),
#   ('patrol', 'O'),
#   ('in', 'O'),
#   ('Baghdad', 'B-geo'),
#   ('Sunday', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('Egyptian', 'B-gpe'),
#   ('police', 'O'),
#   ('have', 'O'),
#   ('arrested', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('16', 'O'),
#   ('members', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('opposition', 'O'),
#   ('Muslim', 'B-org'),
#   ('Brotherhood', 'I-org'),
#   ('as', 'O'),
#   ('parts', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('country', 'O'),
#   ('prepare', 'O'),
#   ('for', 'O'),
#   ('parliamentary', 'O'),
#   ('runoff', 'O'),
#   ('elections', 'O'),
#   ('Saturday', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('arrests', 'O'),
#   ('occurred', 'O'),
#   ('Friday', 'B-tim'),
#   ('in', 'O'),
#   ('Alexandria', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('A', 'O'),
#   ('spokesman', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('Brotherhood', 'B-org'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('arrests', 'O'),
#   ('are', 'O'),
#   ('an', 'O'),
#   ('attempt', 'O'),
#   ('to', 'O'),
#   ('cut', 'O'),
#   ('the', 'O'),
#   ('Brotherhood', 'B-org'),
#   ('off', 'O'),
#   ('from', 'O'),
#   ('its', 'O'),
#   ('supporters', 'O'),
#   ('and', 'O'),
#   ('punishment', 'O'),
#   ('for', 'O'),
#   ('winning', 'O'),
#   ('parliamentary', 'O'),
#   ('seats', 'O'),
#   ('in', 'O'),
#   ('earlier', 'O'),
#   ('elections', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('Muslim', 'B-org'),
#   ('Brotherhood', 'I-org'),
#   ('has', 'O'),
#   ('tripled', 'O'),
#   ('its', 'O'),
#   ('strength', 'O'),
#   ('in', 'O'),
#   ('parliament', 'O'),
#   ('in', 'O'),
#   ('recent', 'O'),
#   ('elections', 'O'),
#   (',', 'O'),
#   ('raising', 'O'),
#   ('the', 'O'),
#   ('party', 'O'),
#   ("'s", 'O'),
#   ('total', 'O'),
#   ('to', 'O'),
#   ('47', 'O'),
#   ('seats', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('In', 'O'),
#   ('Saturday', 'B-tim'),
#   ("'s", 'O'),
#   ('elections', 'O'),
#   (',', 'O'),
#   ('voters', 'O'),
#   ('will', 'O'),
#   ('cast', 'O'),
#   ('ballots', 'O'),
#   ('in', 'O'),
#   ('nine', 'O'),
#   ('provinces', 'O'),
#   ('where', 'O'),
#   ('no', 'O'),
#   ('candidate', 'O'),
#   ('won', 'O'),
#   ('a', 'O'),
#   ('majority', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('previous', 'O'),
#   ('round', 'O'),
#   ('of', 'O'),
#   ('voting', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('Muslim', 'B-org'),
#   ('Brotherhood', 'I-org'),
#   ('is', 'O'),
#   ('banned', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('political', 'O'),
#   ('party', 'O'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('it', 'O'),
#   ('endorses', 'O'),
#   ('so-called', 'O'),
#   ('independent', 'O'),
#   ('candidates', 'O'),
#   ('whose', 'O'),
#   ('allegiance', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('party', 'O'),
#   ('is', 'O'),
#   ('known', 'O'),
#   ('to', 'O'),
#   ('voters', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Hardline', 'O'),
#   ('lawmakers', 'O'),
#   ('in', 'O'),
#   ('Pakistan', 'B-geo'),
#   ("'s", 'O'),
#   ('North', 'B-geo'),
#   ('West', 'I-geo'),
#   ('Frontier', 'I-geo'),
#   ('Province', 'I-geo'),
#   ('have', 'O'),
#   ('pushed', 'O'),
#   ('through', 'O'),
#   ('a', 'O'),
#   ('law', 'O'),
#   ('that', 'O'),
#   ('aims', 'O'),
#   ('to', 'O'),
#   ('ensure', 'O'),
#   ('"', 'O'),
#   ('Islamic', 'O'),
#   ('correctness', 'O'),
#   ('"', 'O'),
#   ('in', 'O'),
#   ('public', 'O'),
#   ('places', 'O'),
#   ('and', 'O'),
#   ('establishes', 'O'),
#   ('a', 'O'),
#   ('morality', 'O'),
#   ('police', 'O'),
#   ('to', 'O'),
#   ('enforce', 'O'),
#   ('decent', 'O'),
#   ('behavior', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('A', 'O'),
#   ('six-party', 'O'),
#   ('coalition', 'O'),
#   ('of', 'O'),
#   ('religious', 'O'),
#   ('based', 'O'),
#   ('parties', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('Mutahida', 'B-org'),
#   ('Majlis-e-Amal', 'I-org'),
#   (',', 'O'),
#   ('dominates', 'O'),
#   ('the', 'O'),
#   ('provincial', 'O'),
#   ('assembly', 'O'),
#   (',', 'O'),
#   ('so', 'O'),
#   ('the', 'O'),
#   ('bill', 'O'),
#   ('was', 'O'),
#   ('easily', 'O'),
#   ('passed', 'O'),
#   ('Thursday', 'B-tim'),
#   ('by', 'O'),
#   ('a', 'O'),
#   ('vote', 'O'),
#   ('of', 'O'),
#   ('68-34', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('provincial', 'O'),
#   ('governor', 'O'),
#   ('must', 'O'),
#   ('still', 'O'),
#   ('sign', 'O'),
#   ('the', 'O'),
#   ('bill', 'O'),
#   ('before', 'O'),
#   ('it', 'O'),
#   ('becomes', 'O'),
#   ('law', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('step', 'O'),
#   ('seen', 'O'),
#   ('only', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('formality', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('proposed', 'O'),
#   ('law', 'O'),
#   ('calls', 'O'),
#   ('for', 'O'),
#   ('setting', 'O'),
#   ('up', 'O'),
#   ('a', 'O'),
#   ('"', 'O'),
#   ('religious', 'O'),
#   ('police', 'O'),
#   ('force', 'O'),
#   ('"', 'O'),
#   ('to', 'O'),
#   ('make', 'O'),
#   ('sure', 'O'),
#   ('people', 'O'),
#   ('adhere', 'O'),
#   ('to', 'O'),
#   ('Islamic', 'O'),
#   ('values', 'O'),
#   ('in', 'O'),
#   ('public', 'O'),
#   ('places', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('entertainment', 'O'),
#   ('outlets', 'O'),
#   ('close', 'O'),
#   ('during', 'O'),
#   ('weekly', 'O'),
#   ('Friday', 'B-tim'),
#   ('prayers', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Violators', 'O'),
#   ('could', 'O'),
#   ('be', 'O'),
#   ('jailed', 'O'),
#   ('for', 'O'),
#   ('up', 'O'),
#   ('to', 'O'),
#   ('six', 'O'),
#   ('months', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('opposition', 'O'),
#   ('has', 'O'),
#   ('denounced', 'O'),
#   ('the', 'O'),
#   ('measure', 'O'),
#   (',', 'O'),
#   ('comparing', 'O'),
#   ('it', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('draconian', 'O'),
#   ('rule', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('former', 'O'),
#   ('Taleban', 'B-org'),
#   ('in', 'O'),
#   ('neighboring', 'O'),
#   ('Afghanistan', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('British', 'B-gpe'),
#   ('police', 'O'),
#   ('say', 'O'),
#   ('they', 'O'),
#   ('have', 'O'),
#   ('arrested', 'O'),
#   ('a', 'O'),
#   ('man', 'O'),
#   ('who', 'O'),
#   ('dressed', 'O'),
#   ('as', 'O'),
#   ('suicide', 'O'),
#   ('bomber', 'O'),
#   ('at', 'O'),
#   ('a', 'O'),
#   ('demonstration', 'O'),
#   ('against', 'O'),
#   ('the', 'O'),
#   ('publication', 'O'),
#   ('of', 'O'),
#   ('cartoons', 'O'),
#   ('depicting', 'O'),
#   ('Islam', 'B-org'),
#   ("'s", 'O'),
#   ('Prophet', 'B-per'),
#   ('Muhammad', 'I-per'),
#   ('.', 'O'),
#   ('', '')],
#  [('Bedfordshire', 'B-gpe'),
#   ('police', 'O'),
#   ('said', 'O'),
#   ('Tuesday', 'B-tim'),
#   ('that', 'O'),
#   ('Omar', 'B-per'),
#   ('Khayam', 'I-per'),
#   ('was', 'O'),
#   ('arrested', 'O'),
#   ('in', 'O'),
#   ('Bedford', 'B-geo'),
#   ('for', 'O'),
#   ('breaching', 'O'),
#   ('the', 'O'),
#   ('conditions', 'O'),
#   ('of', 'O'),
#   ('his', 'O'),
#   ('parole', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Police', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('British', 'B-org'),
#   ('Home', 'I-org'),
#   ('Office', 'I-org'),
#   ('sought', 'O'),
#   ('an', 'O'),
#   ('investigation', 'O'),
#   ('of', 'O'),
#   ('Khayam', 'B-per'),
#   ("'s", 'O'),
#   ('behavior', 'O'),
#   ('after', 'O'),
#   ('he', 'O'),
#   ('was', 'O'),
#   ('photographed', 'O'),
#   ('last', 'O'),
#   ('week', 'O'),
#   ('at', 'O'),
#   ('a', 'O'),
#   ('demonstration', 'O'),
#   ('dressed', 'O'),
#   ('in', 'O'),
#   ('fatigues', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('black', 'O'),
#   ('cap', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('a', 'O'),
#   ('bulky', 'O'),
#   ('belt', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('A', 'O'),
#   ('Home', 'B-org'),
#   ('Office', 'I-org'),
#   ('spokesman', 'O'),
#   ('told', 'O'),
#   ('the', 'O'),
#   ('Associated', 'B-org'),
#   ('Press', 'I-org'),
#   ('that', 'O'),
#   ('if', 'O'),
#   ('the', 'O'),
#   ('behavior', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('paroled', 'O'),
#   ('offender', 'O'),
#   ('gives', 'O'),
#   ('cause', 'O'),
#   ('for', 'O'),
#   ('concern', 'O'),
#   (',', 'O'),
#   ('he', 'O'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('sent', 'O'),
#   ('back', 'O'),
#   ('to', 'O'),
#   ('prison', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('AP', 'B-org'),
#   ('also', 'O'),
#   ('reports', 'O'),
#   ('Khayam', 'B-per'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('on', 'O'),
#   ('parole', 'O'),
#   ('from', 'O'),
#   ('prison', 'O'),
#   ('since', 'O'),
#   ('last', 'O'),
#   ('year', 'O'),
#   ('after', 'O'),
#   ('serving', 'O'),
#   ('half', 'O'),
#   ('his', 'O'),
#   ('six-year', 'O'),
#   ('sentence', 'O'),
#   ('for', 'O'),
#   ('drug', 'O'),
#   ('dealing', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Pakistani', 'B-gpe'),
#   ('officials', 'O'),
#   ('say', 'O'),
#   ('unidentified', 'O'),
#   ('gunmen', 'O'),
#   ('have', 'O'),
#   ('killed', 'O'),
#   ('three', 'O'),
#   ('people', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('a', 'O'),
#   ('former', 'O'),
#   ('government', 'O'),
#   ('minister', 'O'),
#   (',', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('semi-autonomous', 'O'),
#   ('tribal', 'O'),
#   ('region', 'O'),
#   ('bordering', 'O'),
#   ('Afghanistan', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('officials', 'O'),
#   ('say', 'O'),
#   ('prominent', 'O'),
#   ('tribal', 'O'),
#   ('leader', 'O'),
#   ('Malik', 'B-per'),
#   ('Faridullah', 'I-per'),
#   ('Khan', 'I-per'),
#   ('was', 'O'),
#   ('traveling', 'O'),
#   ('in', 'O'),
#   ('South', 'B-geo'),
#   ('Waziristan', 'I-geo'),
#   ('Sunday', 'B-tim'),
#   ('when', 'O'),
#   ('his', 'O'),
#   ('vehicle', 'O'),
#   ('was', 'O'),
#   ('ambushed', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Kani', 'B-geo'),
#   ('Wam', 'I-geo'),
#   ('area', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('His', 'O'),
#   ('driver', 'O'),
#   ('and', 'O'),
#   ('a', 'O'),
#   ('tribal', 'O'),
#   ('elder', 'O'),
#   ('were', 'O'),
#   ('also', 'O'),
#   ('killed', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('No', 'O'),
#   ('one', 'O'),
#   ('has', 'O'),
#   ('claimed', 'O'),
#   ('responsibility', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('killings', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('ambush', 'O'),
#   ('came', 'O'),
#   ('a', 'O'),
#   ('day', 'O'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('commander', 'O'),
#   ('of', 'O'),
#   ('Pakistani', 'B-gpe'),
#   ('troops', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('army', 'O'),
#   ('has', 'O'),
#   ('almost', 'O'),
#   ('completely', 'O'),
#   ('eliminated', 'O'),
#   ('militants', 'O'),
#   ('in', 'O'),
#   ('South', 'B-geo'),
#   ('Waziristan', 'I-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('area', 'O'),
#   ('became', 'O'),
#   ('a', 'O'),
#   ('refuge', 'O'),
#   ('for', 'O'),
#   ('many', 'O'),
#   ('al-Qaida', 'B-org'),
#   ('and', 'O'),
#   ('Taleban', 'B-org'),
#   ('fighters', 'O'),
#   ('after', 'O'),
#   ('the', 'O'),
#   ('Taleban', 'B-org'),
#   ('government', 'O'),
#   ('was', 'O'),
#   ('ousted', 'O'),
#   ('in', 'O'),
#   ('Afghanistan', 'B-geo'),
#   ('in', 'O'),
#   ('2001', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('A', 'O'),
#   ('senior', 'O'),
#   ('Pakistani', 'B-gpe'),
#   ('military', 'O'),
#   ('official', 'O'),
#   ('says', 'O'),
#   ('Pakistan', 'B-gpe'),
#   ('wants', 'O'),
#   ('to', 'O'),
#   ('put', 'O'),
#   ('what', 'O'),
#   ('he', 'O'),
#   ('calls', 'O'),
#   ('the', 'O'),
#   ('"', 'O'),
#   ('sordid', 'O'),
#   ('chapter', 'O'),
#   ('"', 'O'),
#   ('of', 'O'),
#   ('proliferation', 'O'),
#   ('by', 'O'),
#   ('one', 'O'),
#   ('of', 'O'),
#   ('its', 'O'),
#   ('top', 'O'),
#   ('scientists', 'O'),
#   ('behind', 'O'),
#   ('it', 'O'),
#   ('and', 'O'),
#   ('build', 'O'),
#   ('civilian', 'O'),
#   ('nuclear', 'O'),
#   ('ties', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('United', 'B-gpe'),
#   ('States', 'I-gpe'),
#   ('.', 'O'),
#   ('', '')],
#  [('But', 'O'),
#   ('he', 'O'),
#   ('says', 'O'),
#   ('Pakistan', 'B-gpe'),
#   ('is', 'O'),
#   ('not', 'O'),
#   ('ready', 'O'),
#   ('to', 'O'),
#   ('make', 'O'),
#   ('the', 'O'),
#   ('nuclear', 'O'),
#   ('scientist', 'O'),
#   (',', 'O'),
#   ('Abdul', 'B-per'),
#   ('Qadeer', 'I-per'),
#   ('Khan', 'I-per'),
#   (',', 'O'),
#   ('available', 'O'),
#   ('for', 'O'),
#   ('direct', 'O'),
#   ('questioning', 'O'),
#   ('over', 'O'),
#   ('his', 'O'),
#   ('sale', 'O'),
#   ('of', 'O'),
#   ('nuclear', 'O'),
#   ('parts', 'O'),
#   ('and', 'O'),
#   ('secrets', 'O'),
#   ('to', 'O'),
#   ('states', 'O'),
#   ('including', 'O'),
#   ('Iran', 'B-gpe'),
#   (',', 'O'),
#   ('Libya', 'B-gpe'),
#   ('and', 'O'),
#   ('North', 'B-gpe'),
#   ('Korea', 'I-gpe'),
#   ('.', 'O'),
#   ('', '')],
#  [('He', 'O'),
#   ('said', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('reasons', 'O'),
#   ('of', 'O'),
#   ('national', 'O'),
#   ('sensitivities', 'O'),
#   ('for', 'O'),
#   ('not', 'O'),
#   ('making', 'O'),
#   ('him', 'O'),
#   ('available', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('Pakistani', 'B-gpe'),
#   ('official', 'O'),
#   ('was', 'O'),
#   ('giving', 'O'),
#   ('a', 'O'),
#   ('background', 'O'),
#   ('briefing', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('small', 'O'),
#   ('group', 'O'),
#   ('of', 'O'),
#   ('reporters', 'O'),
#   ('in', 'O'),
#   ('Washington', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Khan', 'B-per'),
#   ('admitted', 'O'),
#   ('in', 'O'),
#   ('2004', 'B-tim'),
#   ('that', 'O'),
#   ('he', 'O'),
#   ('operated', 'O'),
#   ('a', 'O'),
#   ('worldwide', 'O'),
#   ('clandestine', 'O'),
#   ('network', 'O'),
#   ('to', 'O'),
#   ('sell', 'O'),
#   ('nuclear', 'O'),
#   ('technology', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('black', 'O'),
#   ('market', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('He', 'O'),
#   ('was', 'O'),
#   ('placed', 'O'),
#   ('under', 'O'),
#   ('house', 'O'),
#   ('arrest', 'O'),
#   ('in', 'O'),
#   ('Islamabad', 'B-geo'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('not', 'O'),
#   ('jailed', 'O'),
#   ('because', 'O'),
#   ('he', 'O'),
#   ('is', 'O'),
#   ('considered', 'O'),
#   ('the', 'O'),
#   ('father', 'O'),
#   ('of', 'O'),
#   ('Pakistan', 'B-geo'),
#   ("'s", 'O'),
#   ('nuclear', 'O'),
#   ('bomb', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('U.S.', 'B-gpe'),
#   ('Army', 'B-org'),
#   ('officials', 'O'),
#   ('said', 'O'),
#   ('Wednesday', 'B-tim'),
#   ('that', 'O'),
#   ('they', 'O'),
#   ('will', 'O'),
#   ('not', 'O'),
#   ('renew', 'O'),
#   ('a', 'O'),
#   ('controversial', 'O'),
#   ('multi-billion', 'O'),
#   ('dollar', 'O'),
#   ('contract', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('Halliburton', 'B-org'),
#   ('company', 'O'),
#   ('to', 'O'),
#   ('provide', 'O'),
#   ('logistical', 'O'),
#   ('support', 'O'),
#   ('to', 'O'),
#   ('U.S.', 'B-gpe'),
#   ('troops', 'O'),
#   ('in', 'O'),
#   ('Iraq', 'B-geo'),
#   ('and', 'O'),
#   ('elsewhere', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Halliburton', 'B-org'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('providing', 'O'),
#   ('a', 'O'),
#   ('long', 'O'),
#   ('list', 'O'),
#   ('of', 'O'),
#   ('services', 'O'),
#   (',', 'O'),
#   ('from', 'O'),
#   ('meals', 'O'),
#   ('to', 'O'),
#   ('communication', 'O'),
#   (',', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('military', 'O'),
#   ('for', 'O'),
#   ('several', 'O'),
#   ('years', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Critics', 'O'),
#   ('of', 'O'),
#   ('Halliburton', 'B-org'),
#   ('include', 'O'),
#   ('auditors', 'O'),
#   ('and', 'O'),
#   ('congressional', 'O'),
#   ('Democrats', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('They', 'O'),
#   ('say', 'O'),
#   ('the', 'O'),
#   ('company', 'O'),
#   ('has', 'O'),
#   ('produced', 'O'),
#   ('some', 'O'),
#   ('shoddy', 'O'),
#   ('work', 'O'),
#   ('and', 'O'),
#   ('charges', 'O'),
#   ('too', 'O'),
#   ('much', 'O'),
#   ('money', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('company', 'O'),
#   ('strongly', 'O'),
#   ('denies', 'O'),
#   ('the', 'O'),
#   ('allegations', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('When', 'O'),
#   ('the', 'O'),
#   ('huge', 'O'),
#   ('contract', 'O'),
#   ('is', 'O'),
#   ('put', 'O'),
#   ('out', 'O'),
#   ('for', 'O'),
#   ('re-bidding', 'O'),
#   (',', 'O'),
#   ('several', 'O'),
#   ('companies', 'O'),
#   ('will', 'O'),
#   ('get', 'O'),
#   ('a', 'O'),
#   ('chance', 'O'),
#   ('to', 'O'),
#   ('compete', 'O'),
#   ('for', 'O'),
#   ('portions', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('work', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Representatives', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('Asia', 'B-org'),
#   ('Pacific', 'I-org'),
#   ('Economic', 'I-org'),
#   ('Cooperation', 'I-org'),
#   ('Business', 'I-org'),
#   ('Advisory', 'I-org'),
#   ('Council', 'I-org'),
#   ('are', 'O'),
#   ('holding', 'O'),
#   ('meetings', 'O'),
#   ('this', 'O'),
#   ('week', 'O'),
#   ('to', 'O'),
#   ('finalize', 'O'),
#   ('their', 'O'),
#   ('annual', 'O'),
#   ('report', 'O'),
#   ('for', 'O'),
#   ('APEC', 'B-org'),
#   ('leaders', 'O'),
#   ('who', 'O'),
#   ('will', 'O'),
#   ('hold', 'O'),
#   ('a', 'O'),
#   ('summit', 'O'),
#   ('on', 'O'),
#   ('September', 'B-tim'),
#   ('8', 'I-tim'),
#   ('and', 'O'),
#   ('9', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('VOA', 'B-org'),
#   ("'s", 'O'),
#   ('Nancy-Amelia', 'B-per'),
#   ('Collins', 'I-per'),
#   ('reports', 'O'),
#   ('from', 'O'),
#   ('Sydney', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Energy', 'O'),
#   (',', 'O'),
#   ('security', 'O'),
#   (',', 'O'),
#   ('climate', 'O'),
#   ('change', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('World', 'B-org'),
#   ('Trade', 'I-org'),
#   ('Organization', 'I-org'),
#   ("'s", 'O'),
#   ('stalled', 'O'),
#   ('negotiations', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('investment', 'O'),
#   ('are', 'O'),
#   ('all', 'O'),
#   ('expected', 'O'),
#   ('to', 'O'),
#   ('be', 'O'),
#   ('among', 'O'),
#   ('the', 'O'),
#   ('major', 'O'),
#   ('topics', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('annual', 'O'),
#   ('report', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('APEC', 'B-org'),
#   ('Business', 'I-org'),
#   ('Advisory', 'I-org'),
#   ('Council', 'I-org'),
#   (',', 'O'),
#   ('known', 'O'),
#   ('as', 'O'),
#   ('ABAC', 'B-org'),
#   ('.', 'O'),
#   ('', '')],
#  [('Tim', 'B-per'),
#   ('Harcourt', 'I-per'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('chief', 'O'),
#   ('economist', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('Australian', 'B-org'),
#   ('Trade', 'I-org'),
#   ('Commission', 'I-org'),
#   (',', 'O'),
#   ('says', 'O'),
#   ('ABAC', 'B-org'),
#   ('plays', 'O'),
#   ('an', 'O'),
#   ('important', 'O'),
#   ('role', 'O'),
#   ('by', 'O'),
#   ('informing', 'O'),
#   ('governments', 'O'),
#   ('where', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('problems', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('"', 'O'),
#   ('The', 'O'),
#   ('most', 'O'),
#   ('important', 'O'),
#   ('thing', 'O'),
#   ('the', 'O'),
#   ('business', 'O'),
#   ('groups', 'O'),
#   ('can', 'O'),
#   ('do', 'O'),
#   ('is', 'O'),
#   ('to', 'O'),
#   ('tell', 'O'),
#   ('the', 'O'),
#   ('governments', 'O'),
#   ('where', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('logjams', 'O'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('obstacles', 'O'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('things', 'O'),
#   ('can', 'O'),
#   ('improve', 'O'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('Harcourt', 'B-per'),
#   ('said', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('"', 'O'),
#   ('I', 'O'),
#   ('think', 'O'),
#   ('actually', 'O'),
#   ('ABAC', 'B-org'),
#   ('has', 'O'),
#   ('played', 'O'),
#   ('a', 'O'),
#   ('pretty', 'O'),
#   ('good', 'O'),
#   ('leadership', 'O'),
#   ('on', 'O'),
#   ('that', 'O'),
#   ('in', 'O'),
#   ('talking', 'O'),
#   ('about', 'O'),
#   ('trade', 'O'),
#   ('facilitation', 'O'),
#   ('and', 'O'),
#   ('basically', 'O'),
#   ('making', 'O'),
#   ('sure', 'O'),
#   ('standards', 'O'),
#   ('are', 'O'),
#   ('consistent', 'O'),
#   ('and', 'O'),
#   ('harmonious', 'O'),
#   ('across', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   ('.', 'O'),
#   ('"', 'O'),
#   ('', '')],
#  [('ABAC', 'B-org'),
#   ('comprises', 'O'),
#   ('up', 'O'),
#   ('to', 'O'),
#   ('three', 'O'),
#   ('members', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('private', 'O'),
#   ('sector', 'O'),
#   ('of', 'O'),
#   ('each', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('21', 'O'),
#   ('economies', 'O'),
#   ('that', 'O'),
#   ('make', 'O'),
#   ('up', 'O'),
#   ('APEC', 'B-org'),
#   ('.', 'O'),
#   ('', '')],
#  [('It', 'O'),
#   ('meets', 'O'),
#   ('three', 'O'),
#   ('times', 'O'),
#   ('a', 'O'),
#   ('year', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('It', 'O'),
#   ('was', 'O'),
#   ('made', 'O'),
#   ('a', 'O'),
#   ('permanent', 'O'),
#   ('body', 'O'),
#   ('in', 'O'),
#   ('1995', 'B-tim'),
#   ('to', 'O'),
#   ('provide', 'O'),
#   ('an', 'O'),
#   ('independent', 'O'),
#   ('business', 'O'),
#   ('perspective', 'O'),
#   ('within', 'O'),
#   ('APEC', 'B-org'),
#   ('.', 'O'),
#   ('', '')],
#  [('Members', 'O'),
#   ('represent', 'O'),
#   ('a', 'O'),
#   ('range', 'O'),
#   ('of', 'O'),
#   ('business', 'O'),
#   ('sectors', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('medium', 'O'),
#   ('and', 'O'),
#   ('small', 'O'),
#   ('businesses', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('ABAC', 'B-org'),
#   ('says', 'O'),
#   ('there', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('need', 'O'),
#   ('for', 'O'),
#   ('businesses', 'O'),
#   ('to', 'O'),
#   ('improve', 'O'),
#   ('energy', 'O'),
#   ('efficiency', 'O'),
#   ('and', 'O'),
#   ('to', 'O'),
#   ('encourage', 'O'),
#   ('conservation', 'O'),
#   ('practices', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('is', 'O'),
#   ('expected', 'O'),
#   ('to', 'O'),
#   ('include', 'O'),
#   ('this', 'O'),
#   ('in', 'O'),
#   ('its', 'O'),
#   ('annual', 'O'),
#   ('report', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Harcourt', 'B-per'),
#   (',', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('Australian', 'B-org'),
#   ('Trade', 'I-org'),
#   ('Commission', 'I-org'),
#   (',', 'O'),
#   ('says', 'O'),
#   ('the', 'O'),
#   ('ABAC', 'B-org'),
#   ('report', 'O'),
#   ('will', 'O'),
#   ('also', 'O'),
#   ('discuss', 'O'),
#   ('ways', 'O'),
#   ('to', 'O'),
#   ('enhance', 'O'),
#   ('regional', 'O'),
#   ('cooperation', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('"', 'O'),
#   ('I', 'O'),
#   ('reckon', 'O'),
#   ('they', 'O'),
#   ("'ll", 'O'),
#   ('talk', 'O'),
#   ('a', 'O'),
#   ('little', 'O'),
#   ('bit', 'O'),
#   ('about', 'O'),
#   ('customs', 'O'),
#   ('and', 'O'),
#   ('quarantine', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('little', 'O'),
#   ('bit', 'O'),
#   ('about', 'O'),
#   ('having', 'O'),
#   ('consistent', 'O'),
#   ('security', 'O'),
#   ('arrangements', 'O'),
#   ('around', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   (',', 'O'),
#   ('"', 'O'),
#   ('Harcourt', 'B-per'),
#   ('said', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('"', 'O'),
#   ('And', 'O'),
#   ('I', 'O'),
#   ('think', 'O'),
#   ('they', 'O'),
#   ("'ll", 'O'),
#   ('want', 'O'),
#   ('a', 'O'),
#   ('one-stop', 'O'),
#   ('shop', 'O'),
#   ('in', 'O'),
#   ('terms', 'O'),
#   ('of', 'O'),
#   ('combining', 'O'),
#   ('security', 'O'),
#   (',', 'O'),
#   ('immigration', 'O'),
#   (',', 'O'),
#   ('customs', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('quarantine', 'O'),
#   ('together', 'O'),
#   ('\x85', 'O'),
#   ('just', 'O'),
#   ('to', 'O'),
#   ('make', 'O'),
#   ('sure', 'O'),
#   ('it', 'O'),
#   ("'s", 'O'),
#   ('more', 'O'),
#   ('streamlined', 'O'),
#   ('and', 'O'),
#   ('provides', 'O'),
#   ('more', 'O'),
#   ('certainty', 'O'),
#   ('.', 'O'),
#   ('"', 'O'),
#   ('', '')],
#  [('ABAC', 'B-org'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('only', 'O'),
#   ('non-governmental', 'O'),
#   ('body', 'O'),
#   ('that', 'O'),
#   ('has', 'O'),
#   ('an', 'O'),
#   ('official', 'O'),
#   ('role', 'O'),
#   ('and', 'O'),
#   ('formal', 'O'),
#   ('dialogue', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('leaders', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('APEC', 'B-org'),
#   ('economies', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('It', 'O'),
#   ('will', 'O'),
#   ('present', 'O'),
#   ('its', 'O'),
#   ('annual', 'O'),
#   ('report', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('APEC', 'B-org'),
#   ('leaders', 'O'),
#   ('meeting', 'O'),
#   ('on', 'O'),
#   ('Saturday', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('Sudan', 'B-gpe'),
#   ("'s", 'O'),
#   ('government', 'O'),
#   ('says', 'O'),
#   ('it', 'O'),
#   ('will', 'O'),
#   ('order', 'O'),
#   ('troops', 'O'),
#   ('to', 'O'),
#   ('end', 'O'),
#   ('attacks', 'O'),
#   ('immediately', 'O'),
#   ('in', 'O'),
#   ('Darfur', 'B-geo'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('is', 'O'),
#   ('asking', 'O'),
#   ('rebels', 'O'),
#   ('to', 'O'),
#   ('do', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Foreign', 'B-per'),
#   ('Minister', 'I-per'),
#   ('Mustafa', 'I-per'),
#   ('Osman', 'I-per'),
#   ('Ismail', 'I-per'),
#   ('says', 'O'),
#   ('Sudanese', 'B-gpe'),
#   ('troops', 'O'),
#   ('will', 'O'),
#   ('also', 'O'),
#   ('withdraw', 'O'),
#   ('to', 'O'),
#   ('positions', 'O'),
#   ('held', 'O'),
#   ('before', 'O'),
#   ('an', 'O'),
#   ('April', 'B-tim'),
#   ('cease-fire', 'O'),
#   (',', 'O'),
#   ('if', 'O'),
#   ('rebels', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('western', 'O'),
#   ('region', 'O'),
#   ('agree', 'O'),
#   ('to', 'O'),
#   ('stop', 'O'),
#   ('attacks', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Mr.', 'B-per'),
#   ('Ismail', 'I-per'),
#   ('announced', 'O'),
#   ('the', 'O'),
#   ('decision', 'O'),
#   ('after', 'O'),
#   ('meeting', 'O'),
#   ('with', 'O'),
#   ('officials', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('United', 'B-org'),
#   ('Nations', 'I-org'),
#   ('and', 'O'),
#   ('African', 'B-org'),
#   ('Union', 'I-org'),
#   ('in', 'O'),
#   ('Khartoum', 'B-geo'),
#   ('Sunday', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('In', 'O'),
#   ('recent', 'O'),
#   ('weeks', 'O'),
#   (',', 'O'),
#   ('AU', 'B-org'),
#   ('officials', 'O'),
#   ('say', 'O'),
#   ('Sudanese', 'B-gpe'),
#   ('troops', 'O'),
#   ('and', 'O'),
#   ('rebels', 'O'),
#   ('have', 'O'),
#   ('repeatedly', 'O'),
#   ('violated', 'O'),
#   ('the', 'O'),
#   ('April', 'B-tim'),
#   ('truce', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Saturday', 'B-tim'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('head', 'O'),
#   ('of', 'O'),
#   ('AU', 'B-org'),
#   ('forces', 'O'),
#   ('in', 'O'),
#   ('Darfur', 'B-geo'),
#   ('accused', 'O'),
#   ('Sudanese', 'B-gpe'),
#   ('government', 'O'),
#   ('helicopters', 'O'),
#   ('of', 'O'),
#   ('bombing', 'O'),
#   ('rebel', 'O'),
#   ('sites', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('South', 'B-geo'),
#   ('Darfur', 'I-geo'),
#   ('village', 'O'),
#   ('of', 'O'),
#   ('Labado', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Khartoum', 'B-gpe'),
#   ('says', 'O'),
#   ('troops', 'O'),
#   ('were', 'O'),
#   ('defending', 'O'),
#   ('their', 'O'),
#   ('positions', 'O'),
#   ('from', 'O'),
#   ('rebel', 'O'),
#   ('attacks', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Aid', 'O'),
#   ('workers', 'O'),
#   ('say', 'O'),
#   ('some', 'O'),
#   ('relief', 'O'),
#   ('efforts', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('suspended', 'O'),
#   ('in', 'O'),
#   ('South', 'B-geo'),
#   ('Darfur', 'I-geo'),
#   ('due', 'O'),
#   ('to', 'O'),
#   ('recent', 'O'),
#   ('attacks', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Indonesian', 'B-gpe'),
#   ('police', 'O'),
#   ('have', 'O'),
#   ('arrested', 'O'),
#   ('three', 'O'),
#   ('men', 'O'),
#   ('in', 'O'),
#   ('connection', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('October', 'B-tim'),
#   ('1', 'I-tim'),
#   ('Bali', 'B-geo'),
#   ('bombings', 'O'),
#   ('that', 'O'),
#   ('left', 'O'),
#   ('23', 'O'),
#   ('people', 'O'),
#   ('dead', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Indonesian', 'B-gpe'),
#   ('police', 'O'),
#   ('said', 'O'),
#   ('Wednesday', 'B-tim'),
#   ('the', 'O'),
#   ('men', 'O'),
#   ('were', 'O'),
#   ('flown', 'O'),
#   ('to', 'O'),
#   ('Bali', 'B-geo'),
#   ('from', 'O'),
#   ('neighboring', 'O'),
#   ('Java', 'B-geo'),
#   ('island', 'O'),
#   ('for', 'O'),
#   ('questioning', 'O'),
#   ('at', 'O'),
#   ('Bali', 'B-geo'),
#   ('police', 'O'),
#   ('headquarters', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Australian', 'B-gpe'),
#   ('and', 'O'),
#   ('French', 'B-gpe'),
#   ('news', 'O'),
#   ('agencies', 'O'),
#   ('say', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('one', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('men', 'O'),
#   ('arrested', 'O'),
#   ('(', 'O'),
#   ('Cholily', 'B-per'),
#   (')', 'O'),
#   ('was', 'O'),
#   ('captured', 'O'),
#   ('during', 'O'),
#   ('a', 'O'),
#   ('series', 'O'),
#   ('of', 'O'),
#   ('counter-terrorism', 'O'),
#   ('raids', 'O'),
#   ('last', 'O'),
#   ('week', 'O'),
#   ('in', 'O'),
#   ('Indonesia', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('raids', 'O'),
#   ('ended', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('death', 'O'),
#   ('of', 'O'),
#   ('alleged', 'O'),
#   ('extremist', 'O'),
#   ('bombmaker', 'O'),
#   ('Azahari', 'B-per'),
#   ('bin', 'I-per'),
#   ('Husin', 'I-per'),
#   ('.', 'O'),
#   ('', '')],
#  [('Indonesian', 'B-gpe'),
#   ('authorities', 'O'),
#   ('blame', 'O'),
#   ('Azahari', 'B-per'),
#   ('bin', 'I-per'),
#   ('Husin', 'I-per'),
#   ('for', 'O'),
#   ('orchestrating', 'O'),
#   ('last', 'O'),
#   ('month', 'O'),
#   ("'s", 'O'),
#   ('attacks', 'O'),
#   ('in', 'O'),
#   ('Bali', 'B-geo'),
#   ('as', 'O'),
#   ('well', 'O'),
#   ('as', 'O'),
#   ('the', 'O'),
#   ('2002', 'B-tim'),
#   ('Bali', 'B-geo'),
#   ('bombings', 'O'),
#   ('that', 'O'),
#   ('killed', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('200', 'O'),
#   ('people', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Gunmen', 'O'),
#   ('have', 'O'),
#   ('shot', 'O'),
#   ('and', 'O'),
#   ('killed', 'O'),
#   ('a', 'O'),
#   ('Roman', 'B-org'),
#   ('Catholic', 'I-org'),
#   ('nun', 'O'),
#   ('and', 'O'),
#   ('her', 'O'),
#   ('bodyguard', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('hospital', 'O'),
#   ('where', 'O'),
#   ('she', 'O'),
#   ('worked', 'O'),
#   ('in', 'O'),
#   ('Islamist-controlled', 'O'),
#   ('Mogadishu', 'B-geo'),
#   (',', 'O'),
#   ('Somalia', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Some', 'O'),
#   ('witnesses', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('Sunday', 'B-tim'),
#   ('shooting', 'O'),
#   ('said', 'O'),
#   ('they', 'O'),
#   ('feared', 'O'),
#   ('the', 'O'),
#   ('attack', 'O'),
#   ('was', 'O'),
#   ('linked', 'O'),
#   ('to', 'O'),
#   ('Muslim', 'O'),
#   ('anger', 'O'),
#   ('toward', 'O'),
#   ('Pope', 'B-per'),
#   ('Benedict', 'I-per'),
#   ('.', 'O'),
#   ('', '')],
#  [('Two', 'O'),
#   ('men', 'O'),
#   ('with', 'O'),
#   ('pistols', 'O'),
#   ('attacked', 'O'),
#   ('the', 'O'),
#   ('nun', 'O'),
#   (',', 'O'),
#   ('Sister', 'B-per'),
#   ('Leonella', 'I-per'),
#   ('Sgorbati', 'I-per'),
#   (',', 'O'),
#   ('after', 'O'),
#   ('she', 'O'),
#   ('finished', 'O'),
#   ('teaching', 'O'),
#   ('a', 'O'),
#   ('medical', 'O'),
#   ('school', 'O'),
#   ('class', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('hospital', 'O'),
#   ('in', 'O'),
#   ('southern', 'O'),
#   ('Mogadishu', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Officials', 'O'),
#   ('say', 'O'),
#   ('one', 'O'),
#   ('suspect', 'O'),
#   ('was', 'O'),
#   ('arrested', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('In', 'O'),
#   ('Rome', 'B-geo'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('Vatican', 'B-org'),
#   ('spokesman', 'O'),
#   ('deplored', 'O'),
#   ('the', 'O'),
#   ('attack', 'O'),
#   ('and', 'O'),
#   ('said', 'O'),
#   ('he', 'O'),
#   ('hoped', 'O'),
#   ('it', 'O'),
#   ('was', 'O'),
#   ('an', 'O'),
#   ('isolated', 'O'),
#   ('event', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('not', 'O'),
#   ('irrationality', 'O'),
#   ('arising', 'O'),
#   ('from', 'O'),
#   ('comments', 'O'),
#   ('made', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('Pope', 'O'),
#   ('which', 'O'),
#   ('angered', 'O'),
#   ('some', 'O'),
#   ('Muslims', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Authorities', 'O'),
#   ('in', 'O'),
#   ('Mogadishu', 'B-geo'),
#   ('have', 'O'),
#   ('not', 'O'),
#   ('determined', 'O'),
#   ('a', 'O'),
#   ('motive', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('shooting', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('pope', 'O'),
#   ('has', 'O'),
#   ('said', 'O'),
#   ('he', 'O'),
#   ('meant', 'O'),
#   ('no', 'O'),
#   ('offense', 'O'),
#   ('to', 'O'),
#   ('Muslims', 'O'),
#   ('when', 'O'),
#   ('he', 'O'),
#   ('quoted', 'O'),
#   ('a', 'O'),
#   ('14', 'O'),
#   ('century', 'O'),
#   ('Byzantine', 'B-per'),
#   ('emperor', 'O'),
#   ('as', 'O'),
#   ('saying', 'O'),
#   ('some', 'O'),
#   ('teachings', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('Prophet', 'B-per'),
#   ('Muhammed', 'I-per'),
#   ('brought', 'O'),
#   ('evil', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('world', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Pakistani', 'B-gpe'),
#   ('forces', 'O'),
#   ('have', 'O'),
#   ('targeted', 'O'),
#   ('militants', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('northwest', 'O'),
#   ('for', 'O'),
#   ('a', 'O'),
#   ('third', 'O'),
#   ('day', 'O'),
#   (',', 'O'),
#   ('launching', 'O'),
#   ('airstrikes', 'O'),
#   ('that', 'O'),
#   ('they', 'O'),
#   ('say', 'O'),
#   ('killed', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('nine', 'O'),
#   ('suspected', 'O'),
#   ('insurgents', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Helicopter', 'O'),
#   ('gunships', 'O'),
#   ('Saturday', 'B-tim'),
#   ('pounded', 'O'),
#   ('militant', 'O'),
#   ('hideouts', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Orakzai', 'B-geo'),
#   ('tribal', 'O'),
#   ('region', 'O'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('many', 'O'),
#   ('Taliban', 'B-org'),
#   ('militants', 'O'),
#   ('are', 'O'),
#   ('believed', 'O'),
#   ('to', 'O'),
#   ('have', 'O'),
#   ('fled', 'O'),
#   ('to', 'O'),
#   ('avoid', 'O'),
#   ('an', 'O'),
#   ('earlier', 'O'),
#   ('military', 'O'),
#   ('offensive', 'O'),
#   ('in', 'O'),
#   ('nearby', 'O'),
#   ('South', 'B-geo'),
#   ('Waziristan', 'I-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('Pakistani', 'B-gpe'),
#   ('military', 'O'),
#   ('launched', 'O'),
#   ('its', 'O'),
#   ('offensive', 'O'),
#   ('in', 'O'),
#   ('Orakzai', 'B-geo'),
#   ('to', 'O'),
#   ('hunt', 'O'),
#   ('Taliban', 'B-org'),
#   ('insurgents', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('So', 'O'),
#   ('far', 'O'),
#   (',', 'O'),
#   ('nearly', 'O'),
#   ('100', 'O'),
#   ('militants', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('reported', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   ('since', 'O'),
#   ('Thursday', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('On', 'O'),
#   ('Friday', 'B-tim'),
#   (',', 'O'),
#   ('five', 'O'),
#   ('soldiers', 'O'),
#   ('were', 'O'),
#   ('killed', 'O'),
#   ('when', 'O'),
#   ('dozens', 'O'),
#   ('of', 'O'),
#   ('militants', 'O'),
#   ('stormed', 'O'),
#   ('a', 'O'),
#   ('military', 'O'),
#   ('checkpoint', 'O'),
#   ('in', 'O'),
#   ('Orakzai', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('At', 'O'),
#   ('least', 'O'),
#   ('32', 'O'),
#   ('suspected', 'O'),
#   ('militants', 'O'),
#   ('were', 'O'),
#   ('killed', 'O'),
#   ('when', 'O'),
#   ('troops', 'O'),
#   ('launched', 'O'),
#   ('a', 'O'),
#   ('counter-attack', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Elsewhere', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('northwest', 'O'),
#   (',', 'O'),
#   ('authorities', 'O'),
#   ('on', 'O'),
#   ('Saturday', 'B-tim'),
#   ('found', 'O'),
#   ('the', 'O'),
#   ('bodies', 'O'),
#   ('of', 'O'),
#   ('six', 'O'),
#   ('people', 'O'),
#   ('who', 'O'),
#   ('had', 'O'),
#   ('been', 'O'),
#   ('shot', 'O'),
#   ('dead', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Kurram', 'B-geo'),
#   ('region', 'O'),
#   ('along', 'O'),
#   ('the', 'O'),
#   ('Afghan', 'B-gpe'),
#   ('border', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('six', 'O'),
#   ('were', 'O'),
#   ('kidnapped', 'O'),
#   ('a', 'O'),
#   ('few', 'O'),
#   ('days', 'O'),
#   ('ago', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('U.S.', 'B-org'),
#   ('military', 'O'),
#   ('in', 'O'),
#   ('Afghanistan', 'B-geo'),
#   ('says', 'O'),
#   ('coalition', 'O'),
#   ('forces', 'O'),
#   ('killed', 'O'),
#   ('14', 'O'),
#   ('Taleban', 'B-org'),
#   ('militants', 'O'),
#   ('in', 'O'),
#   ('separate', 'O'),
#   ('clashes', 'O'),
#   ('this', 'O'),
#   ('week', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('military', 'O'),
#   ('said', 'O'),
#   ('Saturday', 'B-tim'),
#   ('13', 'O'),
#   ('guerrillas', 'O'),
#   ('were', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('two', 'O'),
#   ('encounters', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('central', 'O'),
#   ('province', 'O'),
#   ('of', 'O'),
#   ('Uruzgan', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('One', 'O'),
#   ('Afghan', 'B-gpe'),
#   ('soldier', 'O'),
#   ('was', 'O'),
#   ('killed', 'O'),
#   ('and', 'O'),
#   ('four', 'O'),
#   ('others', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('a', 'O'),
#   ('U.S.', 'B-gpe'),
#   ('soldier', 'O'),
#   (',', 'O'),
#   ('were', 'O'),
#   ('injured', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('fighting', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Another', 'O'),
#   ('militant', 'O'),
#   ('was', 'O'),
#   ('killed', 'O'),
#   ('by', 'O'),
#   ('U.S.', 'B-gpe'),
#   ('troops', 'O'),
#   ('in', 'O'),
#   ('eastern', 'O'),
#   ('Paktika', 'B-geo'),
#   ('province', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Separately', 'O'),
#   (',', 'O'),
#   ('officials', 'O'),
#   ('say', 'O'),
#   ('four', 'O'),
#   ('British', 'B-gpe'),
#   ('soldiers', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('NATO-led', 'O'),
#   ('peacekeeping', 'O'),
#   ('mission', 'O'),
#   ('were', 'O'),
#   ('wounded', 'O'),
#   ('early', 'O'),
#   ('Saturday', 'B-tim'),
#   ('in', 'O'),
#   ('an', 'O'),
#   ('attack', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('northern', 'O'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ('Mazar-e-Sharif', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('It', 'O'),
#   ('was', 'O'),
#   ('not', 'O'),
#   ('immediately', 'O'),
#   ('clear', 'O'),
#   ('what', 'O'),
#   ('motivated', 'O'),
#   ('the', 'O'),
#   ('attack', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Taleban', 'B-org'),
#   ('rebels', 'O'),
#   ('are', 'O'),
#   ('not', 'O'),
#   ('known', 'O'),
#   ('to', 'O'),
#   ('operate', 'O'),
#   ('in', 'O'),
#   ('northern', 'O'),
#   ('Afghanistan', 'B-geo'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('area', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('spared', 'O'),
#   ('much', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('bloodshed', 'O'),
#   ('that', 'O'),
#   ('has', 'O'),
#   ('plagued', 'O'),
#   ('southern', 'O'),
#   ('and', 'O'),
#   ('eastern', 'O'),
#   ('regions', 'O'),
# ...
#   ('Rangoon', 'B-geo'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('praised', 'O'),
#   ('the', 'O'),
#   ('talks', 'O'),
#   ('with', 'O'),
#   ('Vijay', 'B-per'),
#   ('Nambiar', 'I-per'),
#   (',', 'O'),
#   ('chief', 'O'),
#   ('of', 'O'),
#   ('staff', 'O'),
#   ('for', 'O'),
#   ('U.N.', 'B-per'),
#   ('Secretary-General', 'B-org'),
#   ('Ban', 'B-per'),
#   ('Ki-moon', 'I-per'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('65-year-old', 'O'),
#   ('Nobel', 'B-art'),
#   ('peace', 'O'),
#   ('prize', 'O'),
#   ('laureate', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('vocal', 'O'),
#   ('about', 'O'),
#   ('pursuing', 'O'),
#   ('democratic', 'O'),
#   ('reforms', 'O'),
#   ('since', 'O'),
#   ('her', 'O'),
#   ('release', 'B-tim'),
#   ('November', 'I-tim'),
#   ('13', 'I-tim'),
#   ('from', 'I-tim'),
#   ('more', 'I-tim'),
#   ('than', 'I-tim'),
#   ('seven', 'I-tim'),
#   ('years', 'O'),
#   ('of', 'O'),
#   ('house', 'O'),
#   ('arrest', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('But', 'O'),
#   ('she', 'O'),
#   ('has', 'O'),
#   ('also', 'O'),
#   ('been', 'O'),
#   ('careful', 'O'),
#   ('not', 'O'),
#   ('to', 'O'),
#   ('verbally', 'O'),
#   ('challenge', 'O'),
#   ('Burma', 'B-geo'),
#   ("'s", 'O'),
#   ('ruling', 'O'),
#   ('generals', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Nambiar', 'B-per'),
#   ('also', 'O'),
#   ('met', 'O'),
#   ('Saturday', 'B-tim'),
#   ('with', 'O'),
#   ('Burma', 'B-org'),
#   ("'s", 'O'),
#   ('foreign', 'O'),
#   ('minister', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('He', 'O'),
#   ('also', 'O'),
#   ('planned', 'O'),
#   ('to', 'O'),
#   ('meet', 'O'),
#   ('with', 'O'),
#   ('diplomats', 'O'),
#   ('and', 'O'),
#   ('recently-elected', 'O'),
#   ('lawmakers', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Pakistani', 'B-gpe'),
#   ('officials', 'O'),
#   ('say', 'O'),
#   ('security', 'O'),
#   ('forces', 'O'),
#   ('have', 'O'),
#   ('arrested', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('three', 'O'),
#   ('al-Qaida', 'B-org'),
#   ('suspects', 'O'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('gunfight', 'O'),
#   ('near', 'O'),
#   ('the', 'O'),
#   ('Afghan', 'B-gpe'),
#   ('border', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('They', 'O'),
#   ('say', 'O'),
#   ('police', 'O'),
#   ('opened', 'O'),
#   ('fire', 'O'),
#   ('Monday', 'B-tim'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('car', 'O'),
#   ('carrying', 'O'),
#   ('the', 'O'),
#   ('suspects', 'O'),
#   ('outside', 'O'),
#   ('the', 'O'),
#   ('northwestern', 'O'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ('Peshawar', 'B-geo'),
#   ('and', 'O'),
#   ('forced', 'O'),
#   ('it', 'O'),
#   ('to', 'O'),
#   ('stop', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Reports', 'O'),
#   ('say', 'O'),
#   ('one', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('suspects', 'O'),
#   ('escaped', 'O'),
#   ('while', 'O'),
#   ('the', 'O'),
#   ('others', 'O'),
#   ('were', 'O'),
#   ('arrested', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('This', 'O'),
#   ('comes', 'O'),
#   ('less', 'O'),
#   ('than', 'O'),
#   ('a', 'O'),
#   ('week', 'O'),
#   ('after', 'O'),
#   ('Pakistani', 'B-org'),
#   ('officials', 'O'),
#   ('said', 'O'),
#   ('a', 'O'),
#   ('senior', 'O'),
#   ('al-Qaida', 'B-org'),
#   ('explosives', 'O'),
#   ('expert', 'O'),
#   ('was', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('raid', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('suspected', 'O'),
#   ('insurgent', 'O'),
#   ('hideout', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('tribal', 'O'),
#   ('region', 'O'),
#   ('of', 'O'),
#   ('North', 'B-geo'),
#   ('Waziristan', 'I-geo'),
#   ('bordering', 'O'),
#   ('Afghanistan', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Egyptian-born', 'O'),
#   ('Muhsin', 'B-per'),
#   ('Musa', 'I-per'),
#   ('Matwali', 'I-per'),
#   ('Atwah', 'I-per'),
#   ('was', 'O'),
#   ('wanted', 'O'),
#   ('in', 'O'),
#   ('connection', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('1998', 'B-tim'),
#   ('bombings', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('U.S.', 'B-org'),
#   ('embassies', 'O'),
#   ('in', 'O'),
#   ('Kenya', 'B-geo'),
#   ('and', 'O'),
#   ('Tanzania', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('United', 'B-geo'),
#   ('States', 'I-geo'),
#   ('offered', 'O'),
#   ('a', 'O'),
#   ('$', 'O'),
#   ('5', 'O'),
#   ('million', 'O'),
#   ('reward', 'O'),
#   ('for', 'O'),
#   ('his', 'O'),
#   ('capture', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Six', 'O'),
#   ('other', 'O'),
#   ('Islamic', 'O'),
#   ('militants', 'O'),
#   ('were', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('raid', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Rebels', 'O'),
#   ('in', 'O'),
#   ('eastern', 'B-geo'),
#   ('Sudan', 'I-geo'),
#   ('say', 'O'),
#   ('government', 'O'),
#   ('war', 'O'),
#   ('planes', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('bombing', 'O'),
#   ('a', 'O'),
#   ('rebel', 'O'),
#   ('area', 'O'),
#   ('near', 'O'),
#   ('the', 'O'),
#   ('border', 'O'),
#   ('with', 'O'),
#   ('Eritrea', 'B-geo'),
#   (',', 'O'),
#   ('wounding', 'O'),
#   ('several', 'O'),
#   ('people', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('A', 'O'),
#   ('spokesman', 'O'),
#   ('with', 'O'),
#   ('rebels', 'O'),
#   ('known', 'O'),
#   ('as', 'O'),
#   ('the', 'O'),
#   ('Eastern', 'B-org'),
#   ('Front', 'I-org'),
#   ('said', 'O'),
#   ('Friday', 'B-tim'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('bombing', 'O'),
#   ('began', 'O'),
#   ('Thursday', 'B-tim'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Barka', 'B-geo'),
#   ('Valley', 'I-geo'),
#   ('region', 'O'),
#   ('near', 'O'),
#   ('the', 'O'),
#   ('town', 'O'),
#   ('of', 'O'),
#   ('Tokar', 'B-geo'),
#   (',', 'O'),
#   ('120', 'O'),
#   ('kilometers', 'O'),
#   ('south', 'O'),
#   ('Port', 'B-per'),
#   ('Sudan', 'B-gpe'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('Red', 'B-geo'),
#   ('Sea', 'I-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('French', 'B-gpe'),
#   ('news', 'O'),
#   ('agency', 'O'),
#   ('quotes', 'O'),
#   ('a', 'O'),
#   ('rebel', 'O'),
#   ('spokesman', 'O'),
#   ('as', 'O'),
#   ('saying', 'O'),
#   ('many', 'O'),
#   ('civilians', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('injured', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('bombs', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('much', 'O'),
#   ('livestock', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('killed', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('He', 'O'),
#   ('says', 'O'),
#   ('the', 'O'),
#   ('bombings', 'O'),
#   ('continue', 'O'),
#   ('Friday', 'B-tim'),
#   ('.', 'O'),
#   ('', '')],
#  [('There', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('no', 'O'),
#   ('independent', 'O'),
#   ('verification', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('air', 'O'),
#   ('strikes', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Fighting', 'O'),
#   ('broke', 'O'),
#   ('out', 'O'),
#   ('between', 'O'),
#   ('the', 'O'),
#   ('rebels', 'O'),
#   ('and', 'O'),
#   ('government', 'O'),
#   ('troops', 'O'),
#   ('near', 'O'),
#   ('Tokar', 'B-geo'),
#   ('early', 'O'),
#   ('this', 'O'),
#   ('week', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Two', 'O'),
#   ('Sudanese', 'B-gpe'),
#   ('rebel', 'O'),
#   ('factions', 'O'),
#   ('joined', 'O'),
#   ('forces', 'O'),
#   ('in', 'O'),
#   ('February', 'B-tim'),
#   ('to', 'O'),
#   ('form', 'O'),
#   ('the', 'O'),
#   ('Eastern', 'B-org'),
#   ('Front', 'I-org'),
#   ('.', 'O'),
#   ('', '')],
#  [('Pope', 'O'),
#   ('Benedict', 'B-per'),
#   ('XVI', 'I-per'),
#   ('has', 'O'),
#   ('visited', 'O'),
#   ('the', 'O'),
#   ('Italian', 'B-gpe'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ("L'Aquilla", 'B-geo'),
#   ('and', 'O'),
#   ('other', 'O'),
#   ('central', 'O'),
#   ('Italian', 'B-gpe'),
#   ('locales', 'O'),
#   ('devastated', 'O'),
#   ('earlier', 'O'),
#   ('this', 'O'),
#   ('month', 'O'),
#   ('by', 'O'),
#   ('a', 'O'),
#   ('deadly', 'O'),
#   ('earthquake', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('pontiff', 'O'),
#   ('Tuesday', 'B-tim'),
#   ('visited', 'O'),
#   ('several', 'O'),
#   ('sites', 'O'),
#   ('in', 'O'),
#   ("L'Aquilla", 'B-geo'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('medieval', 'O'),
#   ('walled', 'O'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ('70,000', 'O'),
#   ('residents', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('His', 'O'),
#   ('stops', 'O'),
#   ('included', 'O'),
#   ('the', 'O'),
#   ('site', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('partially-collapsed', 'O'),
#   ('college', 'O'),
#   ('dormitory', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('ruins', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('13th', 'B-tim'),
#   ('century', 'I-tim'),
#   ('Santa', 'B-geo'),
#   ('Maria', 'I-geo'),
#   ('di', 'I-geo'),
#   ('Collemaggio', 'I-geo'),
#   ('basilica', 'I-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Speaking', 'O'),
#   ('to', 'O'),
#   ('survivors', 'O'),
#   (',', 'O'),
#   ('he', 'O'),
#   ('called', 'O'),
#   ('for', 'O'),
#   ('"', 'O'),
#   ('an', 'O'),
#   ('examination', 'O'),
#   ('of', 'O'),
#   ('conscience', 'O'),
#   ('"', 'O'),
#   ('by', 'O'),
#   ('builders', 'O'),
#   ('and', 'O'),
#   ('inspectors', 'O'),
#   ('accused', 'O'),
#   ('of', 'O'),
#   ('shoddy', 'O'),
#   ('construction', 'O'),
#   ('practices', 'O'),
#   ('linked', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('collapse', 'O'),
#   ('of', 'O'),
#   ('numerous', 'O'),
#   ('buildings', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Benedict', 'B-per'),
#   ('earlier', 'O'),
#   ('visited', 'O'),
#   ('the', 'O'),
#   ('village', 'O'),
#   ('of', 'O'),
#   ('Onna', 'B-geo'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('40', 'O'),
#   ('of', 'O'),
#   ('300', 'O'),
#   ('residents', 'O'),
#   ('perished', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('6.4', 'O'),
#   ('magnitude', 'O'),
#   ('quake', 'O'),
#   ('on', 'O'),
#   ('April', 'B-tim'),
#   ('6', 'I-tim'),
#   ('reduced', 'O'),
#   ('large', 'O'),
#   ('sections', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('Abruzzo', 'B-geo'),
#   ('region', 'O'),
#   ('to', 'O'),
#   ('rubble', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('Italian', 'B-gpe'),
#   ('government', 'O'),
#   ('has', 'O'),
#   ('earmarked', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('$', 'O'),
#   ('10', 'O'),
#   ('billion', 'O'),
#   ('for', 'O'),
#   ('reconstruction', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Experts', 'O'),
#   ('say', 'O'),
#   ('it', 'O'),
#   ('will', 'O'),
#   ('take', 'O'),
#   ('about', 'O'),
#   ('$', 'O'),
#   ('16', 'O'),
#   ('billion', 'O'),
#   ('to', 'O'),
#   ('rebuild', 'O'),
#   ('the', 'O'),
#   ('area', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('top', 'O'),
#   ('U.S.', 'B-org'),
#   ('military', 'O'),
#   ('commander', 'O'),
#   ('in', 'O'),
#   ('Afghanistan', 'B-geo'),
#   ('says', 'O'),
#   ('Taleban', 'B-org'),
#   ('insurgents', 'O'),
#   ('could', 'O'),
#   ('stage', 'O'),
#   ('a', 'O'),
#   ('high-profile', 'O'),
#   ('attack', 'O'),
#   ('over', 'O'),
#   ('the', 'O'),
#   ('next', 'O'),
#   ('six', 'B-tim'),
#   ('to', 'I-tim'),
#   ('nine', 'I-tim'),
#   ('months', 'O'),
#   (',', 'O'),
#   ('despite', 'O'),
#   ('what', 'O'),
#   ('he', 'O'),
#   ('called', 'O'),
#   ('their', 'O'),
#   ('more', 'O'),
#   ('limited', 'O'),
#   ('"', 'O'),
#   ('terrorist', 'O'),
#   ('capabilities', 'O'),
#   ('.', 'O'),
#   ('"', 'O'),
#   ('', '')],
#  [('Lieutenant', 'B-per'),
#   ('General', 'I-per'),
#   ('David', 'I-per'),
#   ('Barno', 'I-per'),
#   ('told', 'O'),
#   ('reporters', 'O'),
#   ('Saturday', 'B-tim'),
#   ('the', 'O'),
#   ('Taleban', 'B-org'),
#   ('fighters', 'O'),
#   ('are', 'O'),
#   ('becoming', 'O'),
#   ('more', 'O'),
#   ('desperate', 'O'),
#   ('to', 'O'),
#   ('"', 'O'),
#   ('change', 'O'),
#   ('the', 'O'),
#   ('course', 'O'),
#   ('of', 'O'),
#   ('events', 'O'),
#   ('in', 'O'),
#   ('Afghanistan', 'B-geo'),
#   ('.', 'O'),
#   ('"', 'O'),
#   ('', '')],
#  [('General', 'B-per'),
#   ('Barno', 'I-per'),
#   ('said', 'O'),
#   ('he', 'O'),
#   ('expects', 'O'),
#   ('a', 'O'),
#   ('small', 'O'),
#   ('hard-core', 'O'),
#   ('remnant', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('Taleban', 'B-org'),
#   ('to', 'O'),
#   ('continue', 'O'),
#   ('fighting', 'O'),
#   ('even', 'O'),
#   ('as', 'O'),
#   ('the', 'O'),
#   ('group', 'O'),
#   ("'s", 'O'),
#   ('military', 'O'),
#   ('strength', 'O'),
#   ('fades', 'O'),
#   ('away', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Afghanistan', 'B-gpe'),
#   ('is', 'O'),
#   ('scheduled', 'O'),
#   ('to', 'O'),
#   ('hold', 'O'),
#   ('parliamentary', 'O'),
#   ('elections', 'O'),
#   ('on', 'O'),
#   ('September', 'B-tim'),
#   ('18', 'I-tim'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('little', 'O'),
#   ('less', 'O'),
#   ('than', 'O'),
#   ('one', 'B-tim'),
#   ('year', 'O'),
#   ('after', 'O'),
#   ('the', 'O'),
#   ('country', 'O'),
#   ("'s", 'O'),
#   ('first', 'O'),
#   ('direct', 'O'),
#   ('and', 'O'),
#   ('democratic', 'O'),
#   ('presidential', 'O'),
#   ('elections', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Three', 'O'),
#   ('world', 'O'),
#   ('leaders', 'O'),
#   ('who', 'O'),
#   ('had', 'O'),
#   ('key', 'O'),
#   ('roles', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('reunification', 'O'),
#   ('of', 'O'),
#   ('Germany', 'B-geo'),
#   ('gathered', 'O'),
#   ('Saturday', 'B-tim'),
#   ('to', 'O'),
#   ('share', 'O'),
#   ('their', 'O'),
#   ('memories', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('collapse', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('Berlin', 'B-org'),
#   ('Wall', 'I-org'),
#   ('.', 'O'),
#   ('', '')],
#  [('Germany', 'B-geo'),
#   ("'s", 'O'),
#   ('ex-chancellor', 'O'),
#   ('Helmut', 'B-per'),
#   ('Kohl', 'I-per'),
#   (',', 'O'),
#   ('former', 'O'),
#   ('U.S.', 'B-geo'),
#   ('president', 'O'),
#   ('George', 'B-per'),
#   ('Herbert', 'I-per'),
#   ('Walker', 'I-per'),
#   ('Bush', 'I-per'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('former', 'O'),
#   ('Soviet', 'O'),
#   ('leader', 'O'),
#   ('Mikhail', 'B-per'),
#   ('Gorbachev', 'I-per'),
#   ('were', 'O'),
#   ('honored', 'O'),
#   ('at', 'O'),
#   ('a', 'O'),
#   ('gathering', 'O'),
#   ('in', 'O'),
#   ('Berlin', 'B-geo'),
#   ('for', 'O'),
#   ('their', 'O'),
#   ('efforts', 'O'),
#   ('in', 'O'),
#   ('reunifying', 'O'),
#   ('Germany', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('Former', 'O'),
#   ('Chancellor', 'B-per'),
#   ('Kohl', 'I-per'),
#   ('now', 'O'),
#   ('speaks', 'O'),
#   ('with', 'O'),
#   ('difficulty', 'O'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('stroke', 'O'),
#   ('and', 'O'),
#   ('is', 'O'),
#   ('confined', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('wheelchair', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('He', 'O'),
#   ('said', 'O'),
#   ('that', 'O'),
#   ('although', 'O'),
#   ('Germany', 'B-geo'),
#   ("'s", 'O'),
#   ('history', 'O'),
#   ('was', 'O'),
#   ('not', 'O'),
#   ('always', 'O'),
#   ('proud', 'O'),
#   (',', 'O'),
#   ('Germans', 'B-gpe'),
#   ('should', 'O'),
#   ('be', 'O'),
#   ('proud', 'O'),
#   ('of', 'O'),
#   ('their', 'O'),
#   ('country', 'O'),
#   ("'s", 'O'),
#   ('reunification', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('At', 'O'),
#   ('the', 'O'),
#   ('close', 'O'),
#   ('of', 'O'),
#   ('World', 'O'),
#   ('War', 'O'),
#   ('II', 'B-eve'),
#   (',', 'O'),
#   ('Germany', 'B-geo'),
#   ('was', 'O'),
#   ('divided', 'O'),
#   ('into', 'O'),
#   ('two', 'O'),
#   ('separate', 'O'),
#   ('countries', 'O'),
#   ('governed', 'O'),
#   ('under', 'O'),
#   ('separate', 'O'),
#   ('ideologies', 'O'),
#   ('of', 'O'),
#   ('democracy', 'O'),
#   ('and', 'O'),
#   ('communism', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('wall', 'O'),
#   ('was', 'O'),
#   ('built', 'O'),
#   ('starting', 'O'),
#   ('in', 'O'),
#   ('1961', 'B-tim'),
#   ('and', 'O'),
#   ('came', 'O'),
#   ('to', 'O'),
#   ('symbolize', 'O'),
#   ('the', 'O'),
#   ('divide', 'O'),
#   ('between', 'O'),
#   ('the', 'O'),
#   ('so-called', 'O'),
#   ('Iron', 'B-org'),
#   ('Curtain', 'I-org'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('democratic', 'B-geo'),
#   ('West', 'I-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('The', 'O'),
#   ('wall', 'O'),
#   ('was', 'O'),
#   ('breached', 'O'),
#   ('on', 'O'),
#   ('November', 'B-tim'),
#   ('9', 'I-tim'),
#   (',', 'I-tim'),
#   ('1989', 'I-tim'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('worldwide', 'O'),
#   ('audience', 'O'),
#   ('watched', 'O'),
#   ('on', 'O'),
#   ('live', 'O'),
#   ('television', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Thousands', 'O'),
#   ('of', 'O'),
#   ('Icelanders', 'B-gpe'),
#   ('marked', 'O'),
#   ('the', 'O'),
#   ('90th', 'O'),
#   ('anniversary', 'O'),
#   ('of', 'O'),
#   ('sovereignty', 'O'),
#   ('from', 'O'),
#   ('Denmark', 'B-org'),
#   ('Monday', 'B-tim'),
#   ('by', 'O'),
#   ('demanding', 'O'),
#   ('the', 'O'),
#   ('government', 'O'),
#   ('resign', 'O'),
#   ('over', 'O'),
#   ('the', 'O'),
#   ('country', 'O'),
#   ("'s", 'O'),
#   ('economic', 'O'),
#   ('crisis', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  [('Hundreds', 'O'),
#   ('of', 'O'),
#   ('marchers', 'O'),
#   ('tried', 'O'),
#   ('to', 'O'),
#   ('storm', 'O'),
#   ('central', 'O'),
#   ('bank', 'O'),
#   ('headquarters', 'O'),
#   ('in', 'O'),
#   ('Reykjavik', 'B-geo'),
#   ('.', 'O'),
#   ('', '')],
#  [('They', 'O'),
#   ('left', 'O'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('tense', 'O'),
#   ('hour-long', 'O'),
#   ('standoff', 'O'),
#   ('with', 'O'),
#   ('riot', 'O'),
#   ('police', 'O'),
#   ('.', 'O'),
#   ('', '')],
#  ...]

# %%
sentences[0]
# Out:
# [('Thousands', 'O'),
#  ('of', 'O'),
#  ('demonstrators', 'O'),
#  ('have', 'O'),
#  ('marched', 'O'),
#  ('through', 'O'),
#  ('London', 'B-geo'),
#  ('to', 'O'),
#  ('protest', 'O'),
#  ('the', 'O'),
#  ('war', 'O'),
#  ('in', 'O'),
#  ('Iraq', 'B-geo'),
#  ('and', 'O'),
#  ('demand', 'O'),
#  ('the', 'O'),
#  ('withdrawal', 'O'),
#  ('of', 'O'),
#  ('British', 'B-gpe'),
#  ('troops', 'O'),
#  ('from', 'O'),
#  ('that', 'O'),
#  ('country', 'O'),
#  ('.', 'O'),
#  ('', '')]

# %%
sentences[1]
# Out:
# [('Families', 'O'),
#  ('of', 'O'),
#  ('soldiers', 'O'),
#  ('killed', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('conflict', 'O'),
#  ('joined', 'O'),
#  ('the', 'O'),
#  ('protesters', 'O'),
#  ('who', 'O'),
#  ('carried', 'O'),
#  ('banners', 'O'),
#  ('with', 'O'),
#  ('such', 'O'),
#  ('slogans', 'O'),
#  ('as', 'O'),
#  ('"', 'O'),
#  ('Bush', 'B-per'),
#  ('Number', 'O'),
#  ('One', 'O'),
#  ('Terrorist', 'O'),
#  ('"', 'O'),
#  ('and', 'O'),
#  ('"', 'O'),
#  ('Stop', 'O'),
#  ('the', 'O'),
#  ('Bombings', 'O'),
#  ('.', 'O'),
#  ('"', 'O'),
#  ('', '')]

# %%
def pad_sequences(sentences, word_idx, ner_tag_idx, num_words):
    """Pad sequences of sentences to the length of the longest sequence
    """

    X = []
    y = []
    max_len = max(len(sentence) for sentence in sentences) - 1
    print(max_len)
    # max_len = 50

    for sentence in tqdm(sentences):
        word_indices = []
        ner_tag_indices = []
        for word in sentence:
            idx_of_word = word_idx.get(word[0], num_words - 1)
            word_indices.append(idx_of_word)

            idx_of_ner_tag = ner_tag_idx.get(word[1], ner_tag_idx["O"])
            ner_tag_indices.append(idx_of_ner_tag)

        # Padding to the length of the longest sequence
        padded_word_indices = word_indices + [num_words - 1] * (max_len - len(word_indices))
        padded_ner_tag_indices = ner_tag_indices + [ner_tag_idx["O"]] * (max_len - len(ner_tag_indices))

        X.append(torch.tensor(padded_word_indices))
        y.append(torch.tensor(padded_ner_tag_indices))

    X_padded = pad_sequence(X, batch_first=True, padding_value=num_words - 1)
    y_padded = pad_sequence(y, batch_first=True, padding_value=ner_tag_idx["O"])
    
    return X_padded, y_padded

# %%
# Example usage:
X_padded, y_padded = pad_sequences(sentences, word2idx, tag2idx, num_words)
# Out:
# 104
# 100%|██████████| 47959/47959 [00:02<00:00, 21202.35it/s]

# %%
X_padded
# Out:
# tensor([[34083, 11431, 23012,  ..., 35177, 35177, 35177],
#         [29690, 11431, 18666,  ..., 35177, 35177, 35177],
#         [29233, 34823, 29919,  ..., 35177, 35177, 35177],
#         ...,
#         [20640, 15242, 32800,  ..., 35177, 35177, 35177],
#         [29233, 11419, 16632,  ..., 35177, 35177, 35177],
#         [ 4164, 11120, 15633,  ..., 35177, 35177, 35177]])

# %%
y_padded
# Out:
# tensor([[ 7,  7,  7,  ...,  7,  7,  7],
#         [ 7,  7,  7,  ...,  7,  7,  7],
#         [ 7,  7,  7,  ...,  7,  7,  7],
#         ...,
#         [ 7,  7,  7,  ...,  7,  7,  7],
#         [ 7,  7,  7,  ...,  7,  7,  7],
#         [16,  7,  7,  ...,  7,  7,  7]])

# %% [markdown]
# # Outline of Tasks
#
# 1. Simple Bidirectional LSTM model
# 2. Using GloVe word embeddings
# 3. BONUS: LSTM-CNN model

# %% [markdown]
# # 1. Simple Bidirectional LSTM model
#
# - LSTM embedding should be per sentence
# - I currently have each embedding per word

# %%
def split_train_test_data(X, y, train_size: float):
    test_size = 1 - train_size
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
    x_train_tensor = torch.tensor(x_train)
    x_test_tensor = torch.tensor(x_test)

    y_train_tensor = torch.tensor(y_train)
    y_test_tensor = torch.tensor(y_test)

    return x_train_tensor, x_test_tensor, y_train_tensor, y_test_tensor

# %%
train_size = 0.8
x_train, x_test, y_train, y_test = split_train_test_data(X_padded, y_padded, train_size)
# Out:
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_80077/3971341309.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_train_tensor = torch.tensor(x_train)
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_80077/3971341309.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_test_tensor = torch.tensor(x_test)
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_80077/3971341309.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train_tensor = torch.tensor(y_train)
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_80077/3971341309.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test_tensor = torch.tensor(y_test)

# %%
len(x_train), len(x_test), len(y_train), len(y_test)
# Out:
# (38367, 9592, 38367, 9592)

# %% [markdown]
# ## Define BLSTM

# %%
# Define your model
class BiLSTM(nn.Module):
    def __name__(self):
        return "BiLSTM"
    
    def __init__(self, num_words, embedding_dim, hidden_dim, output_dim, dropout):
        super(BiLSTM, self).__init__()
        self.embedding = nn.Embedding(num_words, embedding_dim)
        self.dropout = nn.Dropout(dropout)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, bidirectional=True, batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2, output_dim)

    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.dropout(embedded)
        lstm_out, _ = self.lstm(embedded)
        out = self.fc(lstm_out)
        return out

# %%
embedding_dim = 100
hidden_dim = 256
output_dim = 105
dropout = 0.33

model = BiLSTM(num_words, embedding_dim, hidden_dim, output_dim, dropout)

# %%
# Define optimizer and loss function
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()
batch_size = 32 

# Initialize DataLoader for batching
train_dataset = TensorDataset(x_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
num_epochs = 1
for epoch in range(num_epochs):
    model.train()
    for batch_x, batch_y in tqdm(train_loader):
        optimizer.zero_grad()
        outputs = model(batch_x)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()

    # Validation
    model.eval()
    with torch.no_grad():
        val_outputs = model(x_test)
        val_loss = criterion(val_outputs, y_test)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f}')
# Out:
# 100%|██████████| 1199/1199 [02:07<00:00,  9.42it/s]
# Epoch [1/1], Loss: 0.1777, Val Loss: 0.1746

# %%
# Evaluate the model on test data
with torch.no_grad():
    outputs = model(x_test_tensor)
    _, predicted = torch.max(outputs, 1)
    accuracy = (predicted == y_test_tensor).sum().item() / len(y_test_tensor)
    print('Test Accuracy: {:.7f}%'.format(accuracy))

# Randomly select a sentence for prediction
i = np.random.randint(0, len(x_test))
print("This is sentence:", i)
with torch.no_grad():
    output = model(x_test_tensor[i].unsqueeze(0))
    _, predicted = torch.max(output, 2)
    predicted = predicted.squeeze().numpy()
# Out:
# Test Accuracy: 101.6607590%
# This is sentence: 4069

# %%
print("{:7}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" * 30)
for w, true, pred in zip(x_test[i], y_test[i], predicted):
    print("{:15}{}\t{}".format(words[w], ner_tags[true], ner_tags[pred]))
# Out:
# Word   True 	 Pred
#
# ------------------------------
# anti-Bush      I-eve	B-art
# Jiang          I-eve	I-eve
# 64th           I-eve	I-eve
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 4
#       2 print("-" * 30)
#       3 for w, true, pred in zip(x_test[i], y_test[i], predicted):
# ----> 4     print("{:15}{}\t{}".format(words[w], ner_tags[true], ner_tags[pred]))
#
# IndexError: list index out of range
